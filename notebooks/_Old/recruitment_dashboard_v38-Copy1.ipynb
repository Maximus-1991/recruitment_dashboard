# %%
# TO DO
#How to safely pass in PW (where to store it?)
#Check if can find source in API
#Update DB function: access db, get last entry, then use since_id
#Create functions
#Create docker image
#Host image in cloud
#Flask webapp

# Check why max_id doesnt work

# Write .py functions
# Dockers

# Retrieve all keys in dictionary that do not contain

# need to make pipeline to transform all entries in DF

# %%
from copy import deepcopy
import requests
import numpy as np
import pandas as pd
import datetime
import time
import pytz
import random
from datetime import date
import mysql.connector
from sqlalchemy import create_engine
import pymysql
import matplotlib.pyplot as plt
from collections import Sequence
from itertools import chain, count, tee

headers={'Authorization': 'Bearer 229aa3876e4fc4447460a13da7f57d1be4111202e1d56d4d0231fb932c1e7cd1'}
url = 'https://jdriven.workable.com/spi/v3/'
# Out:
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working

# %%
def locate_element(data,look_up_elem):
    '''
    Function to locate the exact location of a an element in a data structure
    '''
    data_orig = data
    loc_list = []
    
    #### Step 1: Create loop: while look_up_elem not in loc_list
    while look_up_elem not in loc_list:

        data = data_orig
        if loc_list != []:
            for location in loc_list:
                data = data[location]     
        
        #### Step 2: Create loop for each element in data. This element needs to be appended to loc_list if element is found in (sub-levels of) this element
        # Combine step 4 and 5 in one function. Function is to flatten the data and check if look_up_elem is present in data. If element is found, return loc_list
        def check_branche(data):
                    #### Step 2: Check if look_up_element is present on 1st level of data
            if look_up_elem in data:
                loc_list.append(look_up_elem)
                return loc_list

            #### Step 3: If element not present on 1st level, filter out strings and integers from data. Method is different for different data types
            # Note: data_tuple = () (will be problematic, as you cannot append elements to a tuple). We may be able to add items from tuple to list as tuple is also a Sequence

            # Define data_elements
            if type(data)==dict: 
                data_elements = list(data.keys())
            elif type(data)==list: 
                data_elements = list(range(len(data)))
            # elif type(data)==tuple: 
                #data_elements = list(range(len(data)))

            else:
                return "Element not present"
                      
            for element in data_elements:

                data_to_check = data[element]

                # Define data_dict, data_list and data_tuple
                if type(data_to_check)==dict:
                    data_dict = data_to_check
                    data_list = []
                    data_tuple = ()
                elif type(data_to_check)==list:
                    data_dict = {}
                    data_list = data_to_check
                    data_tuple = ()
                elif type(data_to_check)==tuple:
                    data_dict = {}
                    data_list = []
                    data_tuple = data_to_check
                elif type(data_to_check)!=dict and type(data_to_check)!=list and type(data_to_check)!=tuple:
                    continue
                else:
                    return "Error"

                #### Step 5: Enter while loop (is within the for loop of step 4). From the filtered data obtained in step 3, divide the different elements into its data type. Then, flatten type(data) data type first and then the other two data types
                # When look_up_elem is found, append element to loc_list and return loc_list
                while data_dict != {} or data_list != [] or data_tuple !=():
                    # Flatten dictionary and check if element is present on any of the levels and add list elements to data_list
                    # After first round, if any elements were added to data_dict, go through these added elements
                    while data_dict != {}:
                        if look_up_elem in data_dict:
                            loc_list.append(element)
                            return 
                            
                        data_dict_temp = {}
                        # Filter the elements in data_dict
                        for key,value in iter(data_dict.items()):
                            if type(value)==dict:
                                data_dict_temp.update(value)
                            elif type(value)==list:
                                data_list.append(value)
                            #elif type(value)==tuple:
                            #    test_tuple
                            # to check if tuple is also a sequence, can also use chain(element) for this
                            else:
                                "Element is string or integer"
                        data_dict = data_dict_temp

                    # After data_dict is (temporarily) exhausted, go through data_list
                    while data_list != []:
                        if look_up_elem in data_list:
                            loc_list.append(element)
                            return loc_list

                        data_list_temp = []
                        # Filter the elements in data_dict
                        for item in data_list:
                            if type(item)==dict:
                                data_dict.update(item)
                            elif type(item)==list:
                                for i in item:
                                    data_list_temp.append(i)
                            else:
                                "Element is string or integer"
                        data_list = data_list_temp

                    # After data_list is (temporarily) exhausted, go through data_tuple
                    #while data_tuple !=():
                        # Flatten tuple, check if element is present on any of the levels and add dictionary and list elements to data_dict or data_list
                        #pass

            if look_up_elem not in loc_list:
                return "Element not Found"
        check_branche(data)
    
    return loc_list

# %%
def last_api_entry(url,headers):
    '''
    Function to retrieve the last entry in Workable through API
    
    Inputs:
    url: url of the Workable API
    headers: headers to connect to the API
    
    Outputs:
    'id' of the last entry
    '''
    section = 'candidates?'
    limit='100'
    d = datetime.datetime.today().isoformat()
    r_last_entry = requests.get(url+section+'limit='+limit+'&created_after='+d+'.json', headers)
    print(r_last_entry)
    while len(r_last_entry.json()['candidates'])==0:
        d = (d - datetime.timedelta(days=1))
        r_last_entry = requests.get(url+section+'limit='+limit+'&created_after='+d.isoformat()+'.json', headers)
        time.sleep(0.9)
    last_id = r_last_entry.json()['candidates'][-1]['id']
    return last_id

# %%
headers={'Authorization': 'Bearer 229aa3876e4fc4447460a13da7f57d1be4111202e1d56d4d0231fb932c1e7cd1'}
url = 'https://jdriven.workable.com/spi/v3/'
last_api_id = last_api_entry(url=url, headers=headers)
# Out:
# <Response [401]>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-89b51c2fbeaa> in <module>
#       1 headers={'Authorization': 'Bearer 229aa3876e4fc4447460a13da7f57d1be4111202e1d56d4d0231fb932c1e7cd1'}
#       2 url = 'https://jdriven.workable.com/spi/v3/'
# ----> 3 last_api_id = last_api_entry(url=url, headers=headers)
#
# <ipython-input-12-682623bb0875> in last_api_entry(url, headers)
#      15     r_last_entry = requests.get(url+section+'limit='+limit+'&created_after='+d+'.json', headers)
#      16     print(r_last_entry)
# ---> 17     while len(r_last_entry.json()['candidates'])==0:
#      18         d = (d - datetime.timedelta(days=1))
#      19         r_last_entry = requests.get(url+section+'limit='+limit+'&created_after='+d.isoformat()+'.json', headers)
#
# KeyError: 'candidates'

# %%
last_api_id
# Out:
# '48a4545'

# %%
def retrieve_last_db_entry(pw,db_name="candidates5",user='root',host='127.0.0.1',port='',database='recruitment_dashboard'):
    '''
    Function to retrieve candidate id of the last entry in the MySQL DB
    Inputs:
    db_name: Name of the to be created MySQL DB (default is 'candidates2')
    user: user name of db (default is 'root')
    pw: password of database
    host = '127.0.0.1' if connecting to local DB
    host = '<IP address of DB>' if connecting to a DB hosted externally
    port: port (default is no port specified). Format is: ':<port>'
    database: database schema name
    
    Outputs:
    last_entry_id: 'id' of last entry in the MySQL DB
    '''
    conn = mysql.connector.connect(user=user, password=pw,host=host, database=database)
    cursor = conn.cursor()
    sql_select_query = """SELECT id FROM %s ORDER BY created_at DESC LIMIT 1"""%(db_name)
    cursor.execute(sql_select_query)
    last_entry_id = cursor.fetchall() 
    last_entry_id = last_entry_id[0][0]
    conn.close()
    return last_entry_id

# %%
last_db_id = retrieve_last_db_entry(pw='maartens1991',db_name="candidates5",user='root',host='127.0.0.1',port='',database='recruitment_dashboard')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~\Anaconda3\envs\ams\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     471                                raw=raw, buffered=buffered,
# --> 472                                raw_as_string=raw_as_string)
#     473         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Table 'recruitment_dashboard.candidates5' doesn't exist
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-62-910e14a6f282> in <module>
# ----> 1 last_db_id = retrieve_last_db_entry(pw='maartens1991',db_name="candidates5",user='root',host='127.0.0.1',port='',database='recruitment_dashboard')
#
# <ipython-input-61-3ae56c8ed8b9> in retrieve_last_db_entry(pw, db_name, user, host, port, database)
#      17     cursor = conn.cursor()
#      18     sql_select_query = """SELECT id FROM %s ORDER BY created_at DESC LIMIT 1"""%(db_name)
# ---> 19     cursor.execute(sql_select_query)
#      20     last_entry_id = cursor.fetchall()
#      21     last_entry_id = last_entry_id[0][0]
#
# ~\Anaconda3\envs\ams\lib\site-packages\mysql\connector\cursor_cext.py in execute(self, operation, params, multi)
#     264             result = self._cnx.cmd_query(stmt, raw=self._raw,
#     265                                          buffered=self._buffered,
# --> 266                                          raw_as_string=self._raw_as_string)
#     267         except MySQLInterfaceError as exc:
#     268             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
#
# ~\Anaconda3\envs\ams\lib\site-packages\mysql\connector\connection_cext.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     473         except MySQLInterfaceError as exc:
#     474             raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
# --> 475                                              sqlstate=exc.sqlstate)
#     476         except AttributeError:
#     477             if self._unix_socket:
#
# ProgrammingError: 1146 (42S02): Table 'recruitment_dashboard.candidates5' doesn't exist

# %%
last_db_id

# %%
key_list = [
        'id',
        'name',
        'firstname',
        'lastname',
        'headline',
        'subdomain', 
        'shortcode',
        'title',
        'stage',
        'disqualified',
        'disqualification_reason',
        'hired_at',
        'sourced',
        'profile_url',
        'address',
        'phone',
        'email',
        'domain',
        'created_at',
        'updated_at',
]

# %%
def get_cand_data(df_dict, url=url,headers=headers, limit='100', cand_id_list=[], start_id='', start_date='', key_list=key_list):  #request
    if start_date != '':
        created_after = '&created_after='+start_date
    else:
        created_after = ''
    
    if start_id != '':
        start_id = '&since_id='+start_id
    else:
        start_id = ''
    section = 'candidates?'
    request = requests.get(url+section+'limit='+limit+created_after+start_id+'.json', headers=headers)  
    for cand in request.json()['candidates']:
        cand_id_list = cand_id_list
        cand_id_list.append(cand['id'])
        for k in key_list:
            loc = locate_element(cand,k)
            v = cand
            for i in loc:
                v = v[i]
            df_dict[k].append(v)
    try:
        since_id=request.json()['paging']['next'].split("since_id=",1)[1]
        return df_dict, since_id, cand_id_list
    except:
        since_id=None
        return df_dict, since_id, cand_id_list

# %%
def retrieve_activities(url,headers,cand_id_list):
    '''
    Function to create candidate activity dictionary
    Inputs:
    
    df_dict: dictionary containing candidate data
    Outputs:
    
    DataFrame containing the same candidate data as the input
    '''
    # Create DataFrame column labels
    df_dict_cand = {}
    key_list_cand = ['id','tags']
    stage_name_list = [
        'Sourced',
        'Applied',
        'Shortlisted',
        'Talentpool',
        'Review',
        'To schedule',
        'Inplannen 1e gesorek', #not in use anymore --> combine with 'To Schedule' --> delete
        'Inplannen 1e gesprek', #not in use anymore --> combine with 'To Schedule' --> delete
        'inplannen 2e gesprek', #not in use anymore --> combine with '1st Interview' --> delete
        '1st Interview',
        '1e gesprek', #not in use anymore --> combine with '1st Interview' --> delete
        'Interview 1', #not in use anymore --> combine with '1st Interview' --> delete
        '2nd Interview', 
        'Interview 2', #not in use anymore --> combine with '2nd Interview' --> delete
        'Assessment', #not in use anymore --> combine with '2nd Interview' --> delete
        '2e gesprek', #not in use anymore --> combine with '2nd Interview' --> delete
        'Offer',
        'Aanbieding', #not in use anymore --> combine with 'Offer' --> delete
        'Hired',
        'Aangenomen', #not in use anymore --> combine with 'Hired' --> delete
        'Test Fase', #not in use anymore --> delete
        'intern evalueren', #not in use anymore --> delete
        'Plan 1', #not in use anymore --> delete
        'Plan 2', #not in use anymore --> delete
        'Vergaarbak' #not in use anymore --> delete
    ]

    #Add labels to dictionary
    for key in key_list_cand:
        df_dict_cand[key]=[]    
    for key in stage_name_list:
        df_dict_cand[key]=[]
    df_dict_cand['disqualified_at']=[]

    #Retrieve data through API
    section = 'candidates/'
    cnt = 0
    other_st = {'st':[]} # Can be removed later, if appears all stages are listed in stage_name_list

    for cand_id in cand_id_list[:25]: #[:50]  
        print(cand_id)
        r_cand_id = requests.get(url+section+cand_id+'.json', headers=headers)
        time.sleep(1.0)
        print('calls remaining:')
        print(r_cand_id.headers['x-rate-limit-remaining'])
        for k in key_list_cand:
            loc = locate_element(r_cand_id.json()['candidate'],k)
            v = r_cand_id.json()['candidate']
            for i in loc:
                v = v[i]
            df_dict_cand[k].append(v)

        # loop through activities for candidate cand_id
        r_cand_id_act = requests.get(url+section+cand_id+'/activities'+'.json', headers=headers)
        print('calls remaining:')
        print(r_cand_id_act.headers['x-rate-limit-remaining'])
        r_cand_id_act=r_cand_id_act.json()['activities']
        time.sleep(1.0)
        stages = deepcopy(stage_name_list)
        disqualified=False
        for act in r_cand_id_act:
            if act['action']=='disqualified' and disqualified==False:
                df_dict_cand['disqualified_at'].append(act['created_at'])
                disqualified=True
            if act['stage_name'] in stage_name_list:
                if act['stage_name'] not in stages:
                    continue
                else:
                    df_dict_cand[act['stage_name']].append(act['created_at'])
                    stages.remove(act['stage_name'])
            else:
                if act['stage_name']!=None:
                    print(act['stage_name'])
                other_st['st'].append(act['stage_name'])
        if disqualified==False:
            df_dict_cand['disqualified_at'].append(np.nan)
        for remaining_stage in stages:
            df_dict_cand[remaining_stage].append(np.nan)         
        cnt+=1
        print(cnt)
        time.sleep(0.5)
    return df_dict_cand

# %%
def create_df(df_dict):
    '''
    Convert dictionary into pandas DataFrame
    Inputs:
    
    df_dict: dictionary containing candidate data
    Outputs:
    
    DataFrame containing the same candidate data as the input
    '''
    df = pd.DataFrame.from_dict(df_dict, orient='columns')
    return df

# %%
def merge_df(df1,df2,how='left', on=['id']):
    '''
    Function to create candidate activity dictionary
    Inputs:
    
    df_dict: dictionary containing candidate data
    Outputs:
    
    DataFrame containing the same candidate data as the input
    '''    
    df = pd.merge(df1, df2, how=how, on=on)
    return df

# %%
def transform_df(df):
    '''
    Function to transform DataFrame
    Inputs:
    
    df_dict: dictionary containing candidate data
    Outputs:
    
    '''
    #Rename duplicate column name to prevent error when creating SQL database
    df=df.rename(columns = {'sourced':'is_sourced'})
    
    #Replace and Delete columns
    df['To schedule'][(df['Inplannen 1e gesorek'].isnull()==False) & (df['To schedule'].isnull()==True)]=df['Inplannen 1e gesorek'][(df['Inplannen 1e gesorek'].isnull()==False) & (df['To schedule'].isnull()==True)]
    df.drop('Inplannen 1e gesorek',axis=1,inplace = True)
    df['To schedule'][(df['Inplannen 1e gesprek'].isnull()==False) & (df['To schedule'].isnull()==True)]=df['Inplannen 1e gesprek'][(df['Inplannen 1e gesprek'].isnull()==False) & (df['To schedule'].isnull()==True)]
    df.drop('Inplannen 1e gesprek',axis=1,inplace = True)
    df['1st Interview'][(df['inplannen 2e gesprek'].isnull()==False) & (df['1st Interview'].isnull()==True)]=df['inplannen 2e gesprek'][(df['inplannen 2e gesprek'].isnull()==False) & (df['1st Interview'].isnull()==True)]
    df.drop('inplannen 2e gesprek',axis=1,inplace = True)
    df['1st Interview'][(df['1e gesprek'].isnull()==False) & (df['1st Interview'].isnull()==True)]=df['1e gesprek'][(df['1e gesprek'].isnull()==False) & (df['1st Interview'].isnull()==True)]
    df.drop('1e gesprek',axis=1,inplace = True)
    df['1st Interview'][(df['Interview 1'].isnull()==False) & (df['1st Interview'].isnull()==True)]=df['Interview 1'][(df['Interview 1'].isnull()==False) & (df['1st Interview'].isnull()==True)]
    df.drop('Interview 1',axis=1,inplace = True)
    df['2nd Interview'][(df['Interview 2'].isnull()==False) & (df['2nd Interview'].isnull()==True)]=df['Interview 2'][(df['Interview 2'].isnull()==False) & (df['2nd Interview'].isnull()==True)]
    df.drop('Interview 2',axis=1,inplace = True)
    df['2nd Interview'][(df['Assessment'].isnull()==False) & (df['2nd Interview'].isnull()==True)]=df['Assessment'][(df['Assessment'].isnull()==False) & (df['2nd Interview'].isnull()==True)]
    df.drop('Assessment',axis=1,inplace = True)
    df['2nd Interview'][(df['2e gesprek'].isnull()==False) & (df['2nd Interview'].isnull()==True)]=df['2e gesprek'][(df['2e gesprek'].isnull()==False) & (df['2nd Interview'].isnull()==True)]
    df.drop('2e gesprek',axis=1,inplace = True)
    df['Offer'][(df['Aanbieding'].isnull()==False) & (df['Offer'].isnull()==True)]=df['Aanbieding'][(df['Aanbieding'].isnull()==False) & (df['Offer'].isnull()==True)]
    df.drop('Aanbieding',axis=1,inplace = True)

    df['Hired'][(df['Aangenomen'].isnull()==False) & (df['Hired'].isnull()==True)]=df['Aangenomen'][(df['Aangenomen'].isnull()==False) & (df['Hired'].isnull()==True)]
    df.drop('Aangenomen',axis=1,inplace = True)

    # Delete Columns
    df.drop('Test Fase',axis=1,inplace = True)
    df.drop('intern evalueren',axis=1,inplace = True)
    df.drop('Plan 1',axis=1,inplace = True)
    df.drop('Plan 2',axis=1,inplace = True)
    df.drop('Vergaarbak',axis=1,inplace = True)

    #Remove only for now (will be used for source of candidate)
    df.drop('tags',axis=1,inplace = True)

    #Replace np.nan with None, as None is accepted if df is written to a DB using df.to_sql
    #Note that None will only be converted to NULL in SQL if df.to_sql is used, not using executemany
    #NaT is converted as None if using to_sql
    df = df.where((pd.notnull(df)), None)

    #Convert None to 'nan' if getting errors when inserting into MySQL DB
    #df.fillna(value='nan', inplace=True)

    #Convert date columns into DATE columns with specified format
    date_cols = [
            'hired_at',
            'Sourced',
            'Applied',
            'Shortlisted',
            'Talentpool',
            'Review',
            'To schedule',
            '1st Interview',
            '2nd Interview',
            'Offer',
            'Hired',
            'disqualified_at'
    ]
    for date_col in date_cols:
        #df[date_col]=pd.to_datetime(df[date_col])
        df[date_col]=pd.to_datetime(pd.to_datetime(df[date_col]).dt.strftime('%Y-%m-%d'))
    # Make pipeline for this, using typeselector
    for col in df.columns:
        if df[col].dtype == 'object':
            df[col]=df[col].str.encode('ascii', 'ignore').str.decode('ascii')
            df[col][df[col].isnull()==False]=df[col][df[col].isnull()==False].apply(lambda x: x.lower())    
    return df

# %%
def df_to_db(df,pw,db_name='candidates5',user='root:',host='localhost',port='',schema='recruitment_dashboard'):
    '''
    Function to write DataFrame to MySQL DB
    Inputs:
    df: DataFrame containing all candidate data
    db_name: Name of the to be created MySQL DB (default is 'candidates2')
    user: user name of db (default is 'root')
    pw: password of database
    host = 'localhost' if connecting to local DB
    host = '<IP address of DB>' if connecting to a DB hosted externally
    port: port (default is no port specified). Format is: ':<port>'
    schema: database schema name
    
    Outputs:
    Populated MySQL Database
    '''
    engine = create_engine('mysql+pymysql://'+user+pw+'@'+host+port+'/'+schema, echo = False)
    df.to_sql(name = db_name, con = engine, if_exists = 'append', index = False)

# %%
def db_to_df(pw,db_name="candidates5",user='root',host='127.0.0.1',port='',database='recruitment_dashboard'):
    '''
    Function to convert MySQL DB to DataFrame
    Inputs:
    db_name: Name of the to be created MySQL DB (default is 'candidates2')
    user: user name of db (default is 'root')
    pw: password of database
    host = '127.0.0.1' if connecting to local DB
    host = '<IP address of DB>' if connecting to a DB hosted externally
    port: port (default is no port specified). Format is: ':<port>'
    database: database schema name
    
    Outputs:
    Populated MySQL Database
    '''
    conn = mysql.connector.connect(user=user, password=pw,host=host, database=database)
    df = pd.read_sql("SELECT * from "+db_name, conn)
    return df

# %%
def create_db(start_date='2010-01-01T10:10:10Z'):
    last_api_entry(url=url,headers=headers)
    # Create empty df_dict
    df_dict={}
    for key in key_list:
        df_dict[key]=[]
        
def retrieve_all_pages(url,headers,df_dict,since_id,cand_id_list,last_id):
    '''
    Function to get retrieve general candidate data
    Inputs:
    
    Outputs:
    
    
    '''
    try:
        while last_id not in cand_id_list:
            r_cand = requests.get(url+section+'limit='+limit+'&since_id='+since_id+'.json', headers=headers)
            df_dict, since_id, cand_id_list
            get_cand_data(df_dict, url=url,headers=headers, limit='100', cand_id_list=[], start_id='', start_date='', key_list=key_list)
            time.sleep(0.9)
        return df_dict, cand_id_list
    except:
        return df_dict, cand_id_list

# %%
def update_db(pw='maartens1991',db_name="candidates2",user='root',host='127.0.0.1',port='',database='recruitment_dashboard',start_date=''):
    key_list = [
            'id',
            'name',
            'firstname',
            'lastname',
            'headline',
            'subdomain', 
            'shortcode',
            'title',
            'stage',
            'disqualified',
            'disqualification_reason',
            'hired_at',
            'sourced',
            'profile_url',
            'address',
            'phone',
            'email',
            'domain',
            'created_at',
            'updated_at',
    ]
    #last_db_id = retrieve_last_db_entry(pw,db_name,user,host,port,database)
    last_db_id = 'ddb204'
    # Create empty df_dict
    df_dict={}
    for key in key_list:
        df_dict[key]=[]
    headers={'Authorization': 'Bearer 229aa3876e4fc4447460a13da7f57d1be4111202e1d56d4d0231fb932c1e7cd1'}
    url = 'https://jdriven.workable.com/spi/v3/'
    limit='100'
    df_dict, since_id, cand_id_list = get_cand_data(df_dict, url,headers,limit, cand_id_list=[], start_id=last_db_id, start_date=start_date, key_list=key_list)
    while since_id!=None:
        df_dict, since_id, cand_id_list = get_cand_data(df_dict, url, headers, limit, cand_id_list=cand_id_list, start_id=since_id, start_date=start_date, key_list=key_list)
        time.sleep(2.0)
    #Remove first item in cand_id_list to avoid duplicate of the last_db_id
    cand_id_list.remove(last_db_id)
    #Remove first item in all the keys in df_dict to avoid duplicate of the last_db_id
    for key in df_dict.keys():
        df_dict[key].pop(0)
    print('here')
    if cand_id_list!=[]:
        df_dict_cand=retrieve_activities(url,headers,cand_id_list)
        df_cand=create_df(df_dict)
        df_act=create_df(df_dict_cand)
        df_comb=merge_df(df_cand[:25],df_act,how='left', on=['id'])
        df_comb=transform_df(df_comb)
        df_to_db(df_comb,pw,db_name,user+':',host,port,schema=database)
    return df_comb

# %%
df_comb = update_db()
# Out:
# here
# ddb571
# calls remaining:
# 6
# calls remaining:
# 5
# 1
# ddb572
# calls remaining:
# 9
# calls remaining:
# 8
# 2
# ddb582
# calls remaining:
# 7
# calls remaining:
# 6
# 3
# ddb9ca
# calls remaining:
# 5
# calls remaining:
# 4
# 4
# ddbfa2
# calls remaining:
# 9
# calls remaining:
# 8
# 5
# ddf173
# calls remaining:
# 7
# calls remaining:
# 6
# 6
# ddf20e
# calls remaining:
# 5
# calls remaining:
# 4
# 7
# ddf485
# calls remaining:
# 3
# calls remaining:
# 9
# 8
# ddf4cd
# calls remaining:
# 8
# calls remaining:
# 7
# 9
# ddf4d2
# calls remaining:
# 6
# calls remaining:
# 5
# 10
# ddf7b4
# calls remaining:
# 4
# calls remaining:
# 3
# 11
# ddfcbd
# calls remaining:
# 9
# calls remaining:
# 8
# 12
# ddfe84
# calls remaining:
# 7
# calls remaining:
# 6
# 13
# de4088
# calls remaining:
# 5
# calls remaining:
# 4
# 14
# de4522
# calls remaining:
# 9
# calls remaining:
# 8
# 15
# de463d
# calls remaining:
# 7
# calls remaining:
# 6
# 16
# de47a3
# calls remaining:
# 5
# calls remaining:
# 4
# 17
# de489d
# calls remaining:
# 3
# calls remaining:
# 9
# 18
# de53cd
# calls remaining:
# 8
# calls remaining:
# 7
# 19
# de5bfa
# calls remaining:
# 6
# calls remaining:
# 5
# 20
# de5d64
# calls remaining:
# 4
# calls remaining:
# 3
# 21
# df6c94
# calls remaining:
# 9
# calls remaining:
# 8
# 22
# df77d7
# calls remaining:
# 7
# calls remaining:
# 6
# 23
# df78b9
# calls remaining:
# 5
# calls remaining:
# 4
# 24
# df87cf
# calls remaining:
# 3
# calls remaining:
# 9
# 25
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_comb
# Out:
#         id                          name         firstname  \
# 0   ddb571         paula l amaral santos           paula l
# 1   ddb572              gulliver de boer          gulliver
# 2   ddb582                pieter kouyzer            pieter
# 3   ddb9ca       profiel van aris koning  profiel van aris
# 4   ddbfa2                 casper rooker            casper
# 5   ddf173                lennert gijsen           lennert
# 6   ddf20e                  serge juchko             serge
# 7   ddf485                 roel theeuwen              roel
# 8   ddf4cd                    hasan kurt             hasan
# 9   ddf4d2                bert de vreugd              bert
# 10  ddf7b4                 amin ziarkash              amin
# 11  ddfcbd                almar schouten             almar
# 12  ddfe84                bastiaan grisl          bastiaan
# 13  de4088                  thijs immink             thijs
# 14  de4522                robin dronkers             robin
# 15  de463d             willem ottenheijm            willem
# 16  de47a3                    stefan tol               tol
# 17  de489d               sieb van keppel          sieb van
# 18  de53cd         contracten recruiters        contracten
# 19  de5bfa             jan vries lentsch               jan
# 20  de5d64              johannes ransijn          johannes
# 21  df6c94                 erwin van eyk         erwin van
# 22  df77d7                    coskun dag               dag
# 23  df78b9  curriculum vitae kengyip lee               lee
# 24  df87cf             yalda mohammadian             yalda
#
#                     lastname                                      headline  \
# 0              amaral santos                                          None
# 1                    de boer                                          None
# 2                    kouyzer                                          None
# 3                     koning                                          None
# 4                     rooker                                          None
# 5                     gijsen                                          None
# 6                     juchko                                          None
# 7                   theeuwen                                          None
# 8                       kurt                                          None
# 9                  de vreugd                                          None
# 10                  ziarkash                 software developer at qualogy
# 11                  schouten  software architect frontend at powerhouse bv
# 12                     grisl         data science & technology msc student
# 13                    immink                                          None
# 14                  dronkers                                          None
# 15                ottenheijm                                          None
# 16                    stefan                                          None
# 17                    keppel                                          None
# 18                recruiters                                          None
# 19             vries lentsch                                          None
# 20                   ransijn                                          None
# 21                       eyk                                          None
# 22                    coskun                                          None
# 23  curriculum vitae kengyip                                          None
# 24               mohammadian                                          None
#
#    subdomain   shortcode                       title          stage  \
# 0    jdriven  a8c5321f60    big data scientist (bdr)          hired
# 1    jdriven  a8c5321f60    big data scientist (bdr)  2nd interview
# 2    jdriven  a8c5321f60    big data scientist (bdr)     talentpool
# 3    jdriven  a8c5321f60    big data scientist (bdr)  2nd interview
# 4    jdriven  46f9a9bebd  jr. java developer (jcore)          hired
# 5    jdriven  46f9a9bebd  jr. java developer (jcore)          hired
# 6    jdriven  46f9a9bebd  jr. java developer (jcore)     talentpool
# 7    jdriven  46f9a9bebd  jr. java developer (jcore)     talentpool
# 8    jdriven  46f9a9bebd  jr. java developer (jcore)  1st interview
# 9    jdriven  46f9a9bebd  jr. java developer (jcore)     talentpool
# 10   jdriven  46f9a9bebd  jr. java developer (jcore)  2nd interview
# 11   jdriven  9882e4c0ea    java developer (jdriven)     talentpool
# 12   jdriven  a8c5321f60    big data scientist (bdr)     talentpool
# 13   jdriven  46f9a9bebd  jr. java developer (jcore)  1st interview
# 14   jdriven  46f9a9bebd  jr. java developer (jcore)        sourced
# 15   jdriven  46f9a9bebd  jr. java developer (jcore)        sourced
# 16   jdriven  46f9a9bebd  jr. java developer (jcore)        sourced
# 17   jdriven  46f9a9bebd  jr. java developer (jcore)    to schedule
# 18   jdriven  9882e4c0ea    java developer (jdriven)     talentpool
# 19   jdriven  9882e4c0ea    java developer (jdriven)         review
# 20   jdriven  a8c5321f60    big data scientist (bdr)  1st interview
# 21   jdriven  46f9a9bebd  jr. java developer (jcore)     talentpool
# 22   jdriven  46f9a9bebd  jr. java developer (jcore)        sourced
# 23   jdriven  46f9a9bebd  jr. java developer (jcore)         review
# 24   jdriven  a8c5321f60    big data scientist (bdr)        sourced
#
#     disqualified  ...    Applied Shortlisted  Talentpool Review To schedule  \
# 0          False  ...        NaT         NaT         NaT    NaT         NaT
# 1           True  ...        NaT         NaT         NaT    NaT         NaT
# 2          False  ...        NaT         NaT  2019-02-01    NaT         NaT
# 3           True  ...        NaT         NaT         NaT    NaT         NaT
# 4          False  ...        NaT         NaT         NaT    NaT         NaT
# 5          False  ...        NaT         NaT         NaT    NaT         NaT
# 6           True  ...        NaT         NaT         NaT    NaT         NaT
# 7          False  ... 2017-01-06         NaT         NaT    NaT         NaT
# 8           True  ...        NaT         NaT         NaT    NaT         NaT
# 9           True  ...        NaT         NaT         NaT    NaT         NaT
# 10          True  ...        NaT         NaT         NaT    NaT         NaT
# 11          True  ...        NaT         NaT         NaT    NaT         NaT
# 12          True  ... 2016-10-10         NaT         NaT    NaT         NaT
# 13          True  ...        NaT         NaT         NaT    NaT         NaT
# 14          True  ...        NaT         NaT         NaT    NaT         NaT
# 15          True  ...        NaT         NaT         NaT    NaT         NaT
# 16          True  ...        NaT         NaT         NaT    NaT         NaT
# 17          True  ...        NaT         NaT         NaT    NaT         NaT
# 18          True  ...        NaT         NaT         NaT    NaT         NaT
# 19          True  ...        NaT         NaT         NaT    NaT         NaT
# 20          True  ...        NaT         NaT         NaT    NaT         NaT
# 21         False  ...        NaT         NaT  2019-02-01    NaT         NaT
# 22          True  ...        NaT         NaT         NaT    NaT         NaT
# 23          True  ...        NaT         NaT         NaT    NaT         NaT
# 24         False  ...        NaT         NaT         NaT    NaT         NaT
#
#    1st Interview 2nd Interview      Offer      Hired disqualified_at
# 0     2016-09-05    2016-09-26 2016-10-07 2016-10-14             NaT
# 1     2016-09-05    2016-09-20        NaT        NaT      2019-01-28
# 2     2016-09-05           NaT        NaT        NaT      2016-09-11
# 3            NaT    2016-09-05        NaT        NaT      2016-09-09
# 4     2016-09-05    2016-09-08 2016-09-17 2016-09-23             NaT
# 5            NaT    2016-09-14 2016-09-23 2016-09-29             NaT
# 6            NaT           NaT        NaT        NaT      2019-01-09
# 7            NaT    2017-06-23 2017-07-03        NaT             NaT
# 8     2016-09-16           NaT        NaT        NaT      2016-09-23
# 9            NaT    2016-09-07 2016-09-17        NaT      2016-10-06
# 10    2016-09-27    2016-09-27        NaT        NaT      2016-10-17
# 11    2016-09-06    2016-09-23        NaT        NaT      2016-09-29
# 12    2016-10-06           NaT        NaT        NaT      2017-08-09
# 13    2019-01-08           NaT        NaT        NaT      2016-09-15
# 14           NaT           NaT        NaT        NaT      2016-09-07
# 15           NaT           NaT        NaT        NaT      2016-09-07
# 16           NaT           NaT        NaT        NaT      2016-09-07
# 17           NaT           NaT        NaT        NaT      2016-09-09
# 18           NaT           NaT        NaT        NaT      2016-11-10
# 19           NaT           NaT        NaT        NaT      2016-09-06
# 20    2016-09-07           NaT        NaT        NaT      2016-09-19
# 21    2019-01-10           NaT        NaT        NaT             NaT
# 22           NaT           NaT        NaT        NaT      2016-09-09
# 23           NaT           NaT        NaT        NaT      2016-09-08
# 24           NaT           NaT        NaT        NaT             NaT
#
# [25 rows x 31 columns]

# %%
df_db = db_to_df(pw='maartens1991',db_name="candidates",user='root',host='127.0.0.1',port='',database='recruitment_dashboard')

# %%
def retrieve_funnel(df,start_year=2014, start_month=1, start_day=1, end_year=2017, end_month=1, end_day=1):
    '''
    Function to retrieve interview process funnel for specified time frame
    Inputs:
    df: DataFrame containing info about all candidates
    start_date
    end_date

    
    Outputs:
    funnel_dict: dictionary containing the number of candidates in each funnel stage for specified time frame
    '''
    start_date = datetime.datetime(start_year, start_month, start_date)
    end_date = datetime.datetime(end_year, end_month, end_date)

    funnel_stages = [
            'Sourced',
            'Applied',
            'Shortlisted',
            'Talentpool',
            'Review',
            'To schedule',
            '1st Interview',
            '2nd Interview',
            'Offer',
            'Hired',
            'disqualified_at'
    ]
    funnel_dict={}
    for funnel in funnel_stages:
        funnel_dict[funnel]=df[funnel][(df[funnel]>=start_date) & (df[funnel]<=end_date)].count()
    return funnel_dict

# %%
retrieve_funnel(df,start_year=2014, start_month=1, start_day=1, end_year=2017, end_month=1, end_day=1)

# %%
def print_funnel(pw,db_name="candidates5",user='root',host='127.0.0.1',port='',database='recruitment_dashboard',start_year=2014, start_month=1, start_day=1, end_year=2017, end_month=1, end_day=1)
    df = db_to_df(pw,db_name,user,host,port,database)
    funnel_dict=retrieve_funnel(df,start_year, start_month, start_day, end_year, end_month, end_day)
    plt.figure(figsize=(12, 12), dpi=80) # figsize=(width,height)
    plt.bar(range(len(funnel_dict)), list(funnel_dict.values()), align='center')
    plt.xticks(range(len(funnel_dict)), list(funnel_dict.keys()))
    plt.show()

# %%
#Write to Google Cloud DB
engine_cloud = create_engine('mysql+pymysql://root:MjB6KtDfI4pkzKr9@34.90.224.97/recruitment', echo = False)
df_comb.to_sql(name = 'candidates2', con = engine_cloud, if_exists = 'append', index = False)

# %%
# Local DB

try:
    conn = mysql.connector.connect(user='root', password='maartens1991',host='127.0.0.1', database='recruitment_dashboard')
    cursor = conn.cursor()

    # Create table REPLACE WITH CODE BELOW TO MAKE QUERY STATEMENT AND THEN EXECUTE
    # Create sql_create_table_query = ... columns and data type
    col_dtype = []
    for col in df_comb.columns.tolist():
        col_dtype.append(col+' '+str(df_comb[col].dtype))
    
    #Replace objects with TEXT as object is not a data type that can be parsed into CREATE TABLE statement
    #Remove spaces in column name, replace with underscore
    #Rename sourced to is_sourced
    col_dtype = [s.replace('sourced', 'is_sourced') for s in col_dtype]
    col_dtype = [s.replace('To schedule', 'To_schedule') for s in col_dtype]
    col_dtype = [s.replace('1st Interview', '1st_Interview') for s in col_dtype]
    col_dtype = [s.replace('2nd Interview', '2nd_Interview') for s in col_dtype]
    col_dtype = [s.replace('object', 'TEXT') for s in col_dtype]
    col_dtype = [s.replace('<M8[ns]', 'DATE') for s in col_dtype]
    #if column data type is DATE, then dates have to be in the following format (as a string): YYYY-MM-DD
    # All values in column have to be in this format, it does not take a string like 'nan'
    # MySQL does accept NULL (not as a string, just as NULL)
    table_col = ','.join(col_dtype)
    
    sql_create_table_query = """CREATE TABLE candidates (%s)"""%(table_col)
    cursor.execute(sql_create_table_query)
    
    # Save (commit) the changes
    conn.commit()

    # Select column names in order from 1st to last column
    sql_select_query = '''SELECT column_name
    FROM information_schema.columns
    WHERE table_schema = 'recruitment_dashboard'
    AND table_name   = 'candidates'
    ORDER BY ORDINAL_POSITION
    '''

    cursor = conn.cursor()
    cursor.execute(sql_select_query)
    records = cursor.fetchall() 
    columns = []
    for i in records:
        columns.append(i[0])
    col_n = ','.join(columns)

    #Records to insert in SQL table
    records_to_insert = list(df_comb.itertuples(index=False, name=None))
    params = ['%s' for item in records_to_insert[0]] # always use '%s' no matter the data type of the column
    var_string = ','.join(params)

    #Insert all records into table
    sql_insert_query = """INSERT INTO candidates (%s) VALUES (%s);""" %(col_n,var_string)
    cursor = conn.cursor()
    cursor.executemany(sql_insert_query, records_to_insert)
    
    #Commit all changes
    conn.commit()

except (Exception, mysql.connector.Error) as error:
    print ("Error while connecting to SQL DB", error)
finally:
    #Closing database connection
    if(conn):
        cursor.close()
        conn.close()
        print("SQL DB connection is closed")

# %%
# Google Database

try:
    conn = mysql.connector.connect(user='root', password='MjB6KtDfI4pkzKr9',host='34.90.224.97', database='recruitment')
    cursor = conn.cursor()

    # Create table REPLACE WITH CODE BELOW TO MAKE QUERY STATEMENT AND THEN EXECUTE
    # Create sql_create_table_query = ... columns and data type
    col_dtype = []
    for col in df_comb.columns.tolist():
        col_dtype.append(col+' '+str(df_comb[col].dtype))
    
    #Replace objects with TEXT as object is not a data type that can be parsed into CREATE TABLE statement
    #Remove spaces in column name, replace with underscore
    #Rename sourced to is_sourced
    col_dtype = [s.replace('sourced', 'is_sourced') for s in col_dtype]
    col_dtype = [s.replace('To schedule', 'To_schedule') for s in col_dtype]
    col_dtype = [s.replace('1st Interview', '1st_Interview') for s in col_dtype]
    col_dtype = [s.replace('2nd Interview', '2nd_Interview') for s in col_dtype]
    col_dtype = [s.replace('object', 'TEXT') for s in col_dtype]
    table_col = ','.join(col_dtype)
    
    sql_create_table_query = """CREATE TABLE candidates (%s)"""%(table_col)
    cursor.execute(sql_create_table_query)
    
    # Save (commit) the changes
    conn.commit()

    # Select column names in order from 1st to last column
    sql_select_query = '''SELECT column_name
    FROM information_schema.columns
    WHERE table_schema = 'recruitment_dashboard'
    AND table_name   = 'candidates'
    ORDER BY ORDINAL_POSITION
    '''

    cursor = conn.cursor()
    cursor.execute(sql_select_query)
    records = cursor.fetchall() 
    columns = []
    for i in records:
        columns.append(i[0])
    col_n = ','.join(columns)

    #Records to insert in SQL table
    records_to_insert = list(df_comb.itertuples(index=False, name=None))
    params = ['%s' for item in records_to_insert[0]] # always use '%s' no matter the data type of the column
    var_string = ','.join(params)

    #Insert all records into table
    sql_insert_query = """INSERT INTO candidates (%s) VALUES (%s);""" %(col_n,var_string)
    cursor = conn.cursor()
    cursor.executemany(sql_insert_query, records_to_insert)
    
    #Commit all changes
    conn.commit()

except (Exception, mysql.connector.Error) as error:
    print ("Error while connecting to SQL DB", error)
finally:
    #Closing database connection
    if(conn):
        cursor.close()
        conn.close()
        print("SQL DB connection is closed")

# %%
requests.get(url+'candidates'+'.json', headers=headers).json()
# Out:
# {'candidates': [{'id': 'ddb204',
#    'name': 'Niels Drost',
#    'firstname': 'Niels',
#    'lastname': 'Drost',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14527794',
#    'address': None,
#    'phone': '+31 6 1543 4021',
#    'email': 'niels.drost@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T10:05:28Z',
#    'updated_at': '2019-02-01T14:56:34Z'},
#   {'id': 'ddb571',
#    'name': 'Paula L Amaral Santos',
#    'firstname': 'Paula L',
#    'lastname': 'Amaral Santos',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Hired',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': '2016-10-14T10:04:42Z',
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14528671',
#    'address': None,
#    'phone': None,
#    'email': 'paula.amrl@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T10:51:00Z',
#    'updated_at': '2019-01-08T12:17:22Z'},
#   {'id': 'ddb572',
#    'name': 'Gulliver de Boer',
#    'firstname': 'Gulliver',
#    'lastname': 'de Boer',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '2nd Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14528672',
#    'address': None,
#    'phone': '+31612085780',
#    'email': 'gulif87@hotmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T10:51:04Z',
#    'updated_at': '2019-01-28T10:34:24Z'},
#   {'id': 'ddb582',
#    'name': 'Pieter Kouyzer',
#    'firstname': 'Pieter',
#    'lastname': 'Kouyzer',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14528688',
#    'address': None,
#    'phone': '+31(0)85 0020019',
#    'email': 'joris.braspenning@careerresult.nl',
#    'domain': None,
#    'created_at': '2016-09-05T10:52:07Z',
#    'updated_at': '2019-02-01T14:52:58Z'},
#   {'id': 'ddb9ca',
#    'name': 'Profiel Van Aris Koning',
#    'firstname': 'Profiel Van Aris',
#    'lastname': 'Koning',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '2nd Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14529784',
#    'address': None,
#    'phone': None,
#    'email': 'frank.kurstjens@jdriven.com',
#    'domain': None,
#    'created_at': '2016-09-05T11:49:31Z',
#    'updated_at': '2019-01-10T14:29:23Z'},
#   {'id': 'ddbfa2',
#    'name': 'Casper Rooker',
#    'firstname': 'Casper',
#    'lastname': 'Rooker',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Hired',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': '2016-09-23T14:20:02Z',
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14531280',
#    'address': None,
#    'phone': None,
#    'email': 'casper.rooker@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T13:07:18Z',
#    'updated_at': '2019-01-08T12:17:22Z'},
#   {'id': 'ddf173',
#    'name': 'Lennert Gijsen',
#    'firstname': 'Lennert',
#    'lastname': 'Gijsen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Hired',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': '2016-09-29T08:28:40Z',
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544033',
#    'address': None,
#    'phone': None,
#    'email': 'ellis@fahr-becker.nl',
#    'domain': None,
#    'created_at': '2016-09-05T18:40:42Z',
#    'updated_at': '2016-09-29T08:28:40Z'},
#   {'id': 'ddf20e',
#    'name': 'Serge Juchko',
#    'firstname': 'Serge',
#    'lastname': 'Juchko',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544188',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-05T18:48:10Z',
#    'updated_at': '2019-01-09T12:42:13Z'},
#   {'id': 'ddf485',
#    'name': 'Roel Theeuwen',
#    'firstname': 'Roel',
#    'lastname': 'Theeuwen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544819',
#    'address': None,
#    'phone': '0625642501',
#    'email': 'roel.theeuwen@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T19:17:50Z',
#    'updated_at': '2019-10-01T07:40:47Z'},
#   {'id': 'ddf4cd',
#    'name': 'Hasan Kurt',
#    'firstname': 'Hasan',
#    'lastname': 'Kurt',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544891',
#    'address': None,
#    'phone': '495 310 0184',
#    'email': 'ict@aatop.nl',
#    'domain': None,
#    'created_at': '2016-09-05T19:21:04Z',
#    'updated_at': '2016-09-23T13:13:16Z'},
#   {'id': 'ddf4d2',
#    'name': 'Bert de Vreugd',
#    'firstname': 'Bert',
#    'lastname': 'de Vreugd',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544896',
#    'address': None,
#    'phone': None,
#    'email': 'bertdvreugd@msn.com',
#    'domain': None,
#    'created_at': '2016-09-05T19:21:16Z',
#    'updated_at': '2017-03-02T09:12:44Z'},
#   {'id': 'ddf7b4',
#    'name': 'Amin Ziarkash',
#    'firstname': 'Amin',
#    'lastname': 'Ziarkash',
#    'headline': 'Software Developer at Qualogy',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '2nd Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14545634',
#    'address': 'The Hague Area, Netherlands',
#    'phone': None,
#    'email': 'a.ziarkash@gmail.com',
#    'domain': 'search',
#    'created_at': '2016-09-05T19:57:55Z',
#    'updated_at': '2019-01-10T14:29:22Z'},
#   {'id': 'ddfcbd',
#    'name': 'Almar Schouten',
#    'firstname': 'Almar',
#    'lastname': 'Schouten',
#    'headline': 'Software Architect Frontend at Powerhouse Bv',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14546923',
#    'address': 'Utrecht Area, Netherlands',
#    'phone': None,
#    'email': 'almar.schouten@yahoo.com',
#    'domain': 'search',
#    'created_at': '2016-09-05T21:01:07Z',
#    'updated_at': '2019-01-08T12:17:22Z'},
#   {'id': 'ddfe84',
#    'name': 'Bastiaan Grisèl',
#    'firstname': 'Bastiaan',
#    'lastname': 'Grisèl',
#    'headline': 'Data Science & Technology MSc student',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14547378',
#    'address': 'Delft, Provincie Zuid-Holland, Nederland',
#    'phone': '+44 7 44 77 19 31 5',
#    'email': 'bastiaan.grisel@gmail.com',
#    'domain': 'search',
#    'created_at': '2016-09-05T21:24:09Z',
#    'updated_at': '2017-08-09T15:22:32Z'},
#   {'id': 'de4088',
#    'name': 'Thijs Immink',
#    'firstname': 'Thijs',
#    'lastname': 'Immink',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14564278',
#    'address': None,
#    'phone': None,
#    'email': 'r.out@java-professionals.nl',
#    'domain': None,
#    'created_at': '2016-09-06T12:13:16Z',
#    'updated_at': '2019-01-08T15:10:45Z'},
#   {'id': 'de4522',
#    'name': 'Robin Dronkers',
#    'firstname': 'Robin',
#    'lastname': 'Dronkers',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14565456',
#    'address': None,
#    'phone': None,
#    'email': 'robin.dronkers.werk@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-06T12:56:53Z',
#    'updated_at': '2017-12-29T12:36:12Z'},
#   {'id': 'de463d',
#    'name': 'Willem Ottenheijm',
#    'firstname': 'Willem',
#    'lastname': 'Ottenheijm',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14565739',
#    'address': None,
#    'phone': None,
#    'email': 'willemottenheijm@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-06T13:04:51Z',
#    'updated_at': '2017-12-29T12:36:11Z'},
#   {'id': 'de47a3',
#    'name': 'Stefan Tol',
#    'firstname': 'Tol',
#    'lastname': 'Stefan',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14566097',
#    'address': None,
#    'phone': '+31 (0)858882905',
#    'email': 'tolstefan@hotmail.com',
#    'domain': None,
#    'created_at': '2016-09-06T13:12:39Z',
#    'updated_at': '2016-09-07T09:26:35Z'},
#   {'id': 'de489d',
#    'name': 'Sieb Van Keppel',
#    'firstname': 'Sieb Van',
#    'lastname': 'Keppel',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'To schedule',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14566347',
#    'address': None,
#    'phone': None,
#    'email': 'sieb.van.keppel@mail.com',
#    'domain': None,
#    'created_at': '2016-09-06T13:20:26Z',
#    'updated_at': '2016-09-12T09:10:33Z'},
#   {'id': 'de53cd',
#    'name': 'Contracten recruiters',
#    'firstname': 'Contracten',
#    'lastname': 'recruiters',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14569211',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-06T14:28:19Z',
#    'updated_at': '2016-11-10T10:33:33Z'},
#   {'id': 'de5bfa',
#    'name': 'Jan Vries Lentsch',
#    'firstname': 'Jan',
#    'lastname': 'Vries Lentsch',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14571304',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-06T15:06:04Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'de5d64',
#    'name': 'Johannes Ransijn',
#    'firstname': 'Johannes',
#    'lastname': 'Ransijn',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14571666',
#    'address': None,
#    'phone': None,
#    'email': 'bram@careervalue.nl',
#    'domain': None,
#    'created_at': '2016-09-06T15:15:05Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'df6c94',
#    'name': 'Erwin Van Eyk',
#    'firstname': 'Erwin Van',
#    'lastname': 'Eyk',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14641090',
#    'address': None,
#    'phone': None,
#    'email': 'erwinvaneyk@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-08T08:02:15Z',
#    'updated_at': '2019-06-11T07:57:35Z'},
#   {'id': 'df77d7',
#    'name': 'Coskun Dag',
#    'firstname': 'Dag',
#    'lastname': 'Coskun',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14643973',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-08T09:45:57Z',
#    'updated_at': '2016-09-09T13:33:22Z'},
#   {'id': 'df78b9',
#    'name': 'Curriculum Vitae Kengyip Lee',
#    'firstname': 'Lee',
#    'lastname': 'Curriculum Vitae Kengyip',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14644199',
#    'address': None,
#    'phone': '+31 6 14563955',
#    'email': 'kengyiplee@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-08T09:56:05Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'df87cf',
#    'name': 'Yalda Mohammadian',
#    'firstname': 'Yalda',
#    'lastname': 'Mohammadian',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14648061',
#    'address': None,
#    'phone': '(020) 2401 401',
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-08T12:13:29Z',
#    'updated_at': '2018-06-02T07:41:16Z'},
#   {'id': 'df8812',
#    'name': 'Matthijs Brouns',
#    'firstname': 'Matthijs',
#    'lastname': 'Brouns',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14648128',
#    'address': None,
#    'phone': None,
#    'email': 'matthijs.brouns@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-08T12:16:40Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'dfaacc',
#    'name': 'Rutger de Graaf',
#    'firstname': 'Rutger',
#    'lastname': 'de Graaf',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'To schedule',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14657018',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-08T16:11:44Z',
#    'updated_at': '2017-12-29T12:36:11Z'},
#   {'id': 'dfaf18',
#    'name': 'Shoaib Amini',
#    'firstname': 'Shoaib',
#    'lastname': 'Amini',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14658118',
#    'address': None,
#    'phone': '23955-6900',
#    'email': 'renee.moerenhout+shoaibamini@jdriven.com',
#    'domain': None,
#    'created_at': '2016-09-08T16:42:36Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'e00269',
#    'name': 'Veli Aydin',
#    'firstname': 'Veli',
#    'lastname': 'Aydin',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14679447',
#    'address': None,
#    'phone': None,
#    'email': 'v_aydin@live.nl',
#    'domain': None,
#    'created_at': '2016-09-09T07:46:45Z',
#    'updated_at': '2016-09-20T07:05:08Z'},
#   {'id': 'e01304',
#    'name': 'Bram Neijt',
#    'firstname': 'Bram',
#    'lastname': 'Neijt',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Hired',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': '2016-10-04T11:02:37Z',
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14683698',
#    'address': None,
#    'phone': '+31612255344',
#    'email': 'bneijt@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T11:53:34Z',
#    'updated_at': '2016-10-04T11:02:37Z'},
#   {'id': 'e01384',
#    'name': 'Tim van Grieken',
#    'firstname': 'Tim Van',
#    'lastname': 'Grieken',
#    'headline': 'Web Analytics, Data Science and Social Psychology.',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14683826',
#    'address': 'Amsterdam, North Holland, Netherlands',
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-09T12:10:19Z',
#    'updated_at': '2016-09-29T08:21:05Z'},
#   {'id': 'e03bca',
#    'name': 'Dave Van Eijck',
#    'firstname': 'Dave Van',
#    'lastname': 'Eijck',
#    'headline': 'Senior Developer at 42.nl',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'To schedule',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14694136',
#    'address': 'Den Haag en omgeving, Nederland',
#    'phone': None,
#    'email': None,
#    'domain': 'search',
#    'created_at': '2016-09-09T18:16:42Z',
#    'updated_at': '2017-02-23T11:12:48Z'},
#   {'id': 'e096e5',
#    'name': 'Roy De Groot',
#    'firstname': 'Roy De',
#    'lastname': 'Groot',
#    'headline': 'Data Analytics Consultant & Data Science Analyst',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14717459',
#    'address': 'Utrecht en omgeving, Nederland',
#    'phone': None,
#    'email': None,
#    'domain': 'search',
#    'created_at': '2016-09-10T18:46:39Z',
#    'updated_at': '2019-03-05T11:17:22Z'},
#   {'id': 'e11c35',
#    'name': 'Mark Oost',
#    'firstname': 'Mark',
#    'lastname': 'Oost',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14751587',
#    'address': None,
#    'phone': '(020) 2401 401',
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-12T06:32:11Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'e12f8f',
#    'name': 'Uri Shimron',
#    'firstname': 'Uri',
#    'lastname': 'Shimron',
#    'headline': 'Senior data-analist at Coney',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14756541',
#    'address': 'The Hague, South Holland',
#    'phone': '+31888963850',
#    'email': 'shimron@localinfo.nl',
#    'domain': None,
#    'created_at': '2016-09-12T11:46:59Z',
#    'updated_at': '2017-12-29T12:36:10Z'},
#   {'id': 'e1cca6',
#    'name': 'Jeffrey Powell',
#    'firstname': 'Jeffrey',
#    'lastname': 'Powell',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '2nd Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14796756',
#    'address': None,
#    'phone': '+31622924942',
#    'email': 'farid@careervalue.nl',
#    'domain': None,
#    'created_at': '2016-09-13T13:26:27Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'e23fde',
#    'name': 'Bert Carsouw',
#    'firstname': 'Bert',
#    'lastname': 'Carsouw',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14826252',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-14T06:09:40Z',
#    'updated_at': '2017-12-12T14:29:28Z'},
#   {'id': 'e27389',
#    'name': 'Marc Huls',
#    'firstname': 'Marc',
#    'lastname': 'Huls',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14839479',
#    'address': None,
#    'phone': None,
#    'email': 'jvandiest@spilberg.nl',
#    'domain': None,
#    'created_at': '2016-09-14T15:35:29Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'e2d0e6',
#    'name': 'Pim Schellart',
#    'firstname': 'Pim',
#    'lastname': 'Schellart',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Shortlisted',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14863380',
#    'address': None,
#    'phone': '+1 (609) 356-4519',
#    'email': 'p.schellart@princeton.edu',
#    'domain': None,
#    'created_at': '2016-09-15T08:07:44Z',
#    'updated_at': '2019-01-15T10:35:52Z'},
#   {'id': 'e2d1ee',
#    'name': 'Sander Kerkdijk',
#    'firstname': 'Sander',
#    'lastname': 'Kerkdijk',
#    'headline': 'Data Scientist @ Aneto BV Bunnink',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14863644',
#    'address': None,
#    'phone': '06-22 55 71 92',
#    'email': 'sander.kerkdijk@aneto.nl',
#    'domain': None,
#    'created_at': '2016-09-15T08:24:05Z',
#    'updated_at': '2019-09-20T13:20:26Z'},
#   {'id': 'e2d3f3',
#    'name': 'Kia Eisinga',
#    'firstname': 'Kia',
#    'lastname': 'Eisinga',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14864161',
#    'address': None,
#    'phone': None,
#    'email': 'kiaeisinga@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-15T08:48:42Z',
#    'updated_at': '2019-08-28T13:18:31Z'},
#   {'id': 'e2d4ac',
#    'name': 'Kaitlin Nadson',
#    'firstname': 'Kaitlin',
#    'lastname': 'Nadson',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14864346',
#    'address': None,
#    'phone': '+31 (0)6 136 294 81',
#    'email': 'kaitlin.nadson@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-15T08:57:58Z',
#    'updated_at': '2016-09-26T13:00:44Z'},
#   {'id': 'e2d5c4',
#    'name': 'Juan Adriaanse',
#    'firstname': 'Juan',
#    'lastname': 'Adriaanse',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'To schedule',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14864626',
#    'address': None,
#    'phone': '285 97 272',
#    'email': 'adriaanse.juan@gmail.nl',
#    'domain': None,
#    'created_at': '2016-09-15T09:15:52Z',
#    'updated_at': '2016-10-17T13:43:13Z'},
#   {'id': 'e2d75b',
#    'name': 'Mar Maykel Vink',
#    'firstname': 'Mar',
#    'lastname': 'Maykel Vink',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14865033',
#    'address': None,
#    'phone': None,
#    'email': 'maykel@maykelvink.nl',
#    'domain': None,
#    'created_at': '2016-09-15T09:31:28Z',
#    'updated_at': '2019-01-08T12:17:20Z'},
#   {'id': 'e2e573',
#    'name': 'Lucas Maasse',
#    'firstname': 'Lucas',
#    'lastname': 'Maasse',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14868641',
#    'address': None,
#    'phone': '0655967587',
#    'email': 'lucasmaasse@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-15T12:42:16Z',
#    'updated_at': '2019-06-03T07:59:29Z'},
#   {'id': 'e3016e',
#    'name': 'Benjamin Van Den Akker',
#    'firstname': 'Benjamin Van Den',
#    'lastname': 'Akker',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14875804',
#    'address': None,
#    'phone': '06 44872734',
#    'email': 'benjaminvandenakker@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-15T16:18:29Z',
#    'updated_at': '2019-01-08T12:17:20Z'},
#   {'id': 'e36bc6',
#    'name': 'Dana Bˇalibanu',
#    'firstname': 'Dana',
#    'lastname': 'Bˇalibanu',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14903028',
#    'address': None,
#    'phone': '+31 (627) 206 495',
#    'email': 'danabalibanu@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-16T13:47:44Z',
#    'updated_at': '2019-01-10T14:23:30Z'},
#   {'id': 'e37c6f',
#    'name': 'Mark Vervuurt',
#    'firstname': 'Mark',
#    'lastname': 'Vervuurt',
#    'headline': 'Senior Big Data / Java Consultant at Capgemini',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14907293',
#    'address': 'Utrecht, Netherlands',
#    'phone': None,
#    'email': 'm.a.vervuurt@gmail.com',
#    'domain': 'search',
#    'created_at': '2016-09-16T16:06:43Z',
#    'updated_at': '2019-02-25T08:22:48Z'},
#   {'id': 'e3c572',
#    'name': 'Pearl Roman',
#    'firstname': 'Pearl',
#    'lastname': 'Roman',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14925984',
#    'address': None,
#    'phone': '+31619424969',
#    'email': 'pearlroman@hotmail.com',
#    'domain': None,
#    'created_at': '2016-09-17T09:38:43Z',
#    'updated_at': '2019-01-08T12:17:20Z'}],
#  'paging': {'next': 'https://jdriven.workable.com/spi/v3/candidates?limit=50&since_id=e48b5d'}}

# %%
requests.get(url+'candidates/48a4545'+'.json', headers=headers).json()
# Out:
# {'candidate': {'id': '48a4545',
#   'name': 'Jens Dudink',
#   'firstname': 'Jens',
#   'lastname': 'Dudink',
#   'headline': None,
#   'image_url': None,
#   'account': {'subdomain': 'jdriven',
#    'name': 'JDriven/JCore/BigData Republic'},
#   'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#   'stage': 'Review',
#   'disqualified': False,
#   'disqualified_at': None,
#   'disqualification_reason': None,
#   'hired_at': None,
#   'sourced': True,
#   'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/76169331',
#   'address': None,
#   'phone': '(+31) 6 2446 4393',
#   'email': 'ja.dudink@gmail.com',
#   'outbound_mailbox': '4f35nkmjatqo@outbound.workablemail.com',
#   'domain': None,
#   'uploader_id': 'a132a',
#   'created_at': '2019-10-04T12:32:48Z',
#   'updated_at': '2019-10-06T10:33:21Z',
#   'cover_letter': None,
#   'summary': None,
#   'education_entries': [],
#   'experience_entries': [],
#   'skills': [],
#   'answers': [],
#   'resume_url': 'https://workablehr.s3.amazonaws.com/uploads/137223/686542/76169331/download/JensDudinkCV__2_.pdf?X-Amz-Expires=60000&X-Amz-Date=20191006T134651Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIR2MIE33PRKXR4CA%2F20191006%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=2513d4c02b880f76376f863a2d9040ef98fd585e5eed8556ac1474d0b8f874c7',
#   'social_profiles': [{'type': 'linkedin',
#     'name': 'LinkedIn',
#     'username': 'in/jensdudink',
#     'url': 'http://linkedin.com/in/jensdudink'}],
#   'tags': ['osella', 'week40_2019']}}

# %%
requests.get(url+'candidates/422cf23'+'.json', headers=headers).json()
# Out:
# {'candidate': {'id': '422cf23',
#   'name': 'Bart De Gelder',
#   'firstname': 'Bart',
#   'lastname': 'De Gelder',
#   'headline': None,
#   'image_url': None,
#   'account': {'subdomain': 'jdriven',
#    'name': 'JDriven/JCore/BigData Republic'},
#   'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#   'stage': 'Applied',
#   'disqualified': False,
#   'disqualified_at': None,
#   'disqualification_reason': None,
#   'hired_at': None,
#   'sourced': True,
#   'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/69388881',
#   'address': None,
#   'phone': None,
#   'email': None,
#   'outbound_mailbox': '4ed006ytwwz-@outbound.workablemail.com',
#   'domain': None,
#   'uploader_id': '3c194',
#   'created_at': '2019-06-25T06:59:22Z',
#   'updated_at': '2019-07-02T07:00:22Z',
#   'cover_letter': None,
#   'summary': None,
#   'education_entries': [],
#   'experience_entries': [],
#   'skills': [],
#   'answers': [],
#   'resume_url': 'https://workablehr.s3.amazonaws.com/uploads/137223/686542/69388881/download/Profile__4_.pdf?X-Amz-Expires=60000&X-Amz-Date=20191004T180104Z&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIR2MIE33PRKXR4CA%2F20191004%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-SignedHeaders=host&X-Amz-Signature=d827cd7c786f885ef019b8cd896587f51fcdac6b3b2f35af39979cc43b0f2f13',
#   'social_profiles': [{'type': 'linkedin',
#     'name': 'LinkedIn',
#     'username': 'in/bart-de-gelder-665a31a9',
#     'url': 'https://www.linkedin.com/in/bart-de-gelder-665a31a9'}],
#   'tags': []}}

# %%
section = 'candidates?'
start_date = '2010-01-01T10:10:10Z'
r_cand = requests.get(url+section+'limit=100&created_after='+start_date+'.json', headers=headers)

# %%
r_cand.json()
# Out:
# {'candidates': [{'id': 'ddb204',
#    'name': 'Niels Drost',
#    'firstname': 'Niels',
#    'lastname': 'Drost',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14527794',
#    'address': None,
#    'phone': '+31 6 1543 4021',
#    'email': 'niels.drost@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T10:05:28Z',
#    'updated_at': '2019-02-01T14:56:34Z'},
#   {'id': 'ddb571',
#    'name': 'Paula L Amaral Santos',
#    'firstname': 'Paula L',
#    'lastname': 'Amaral Santos',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Hired',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': '2016-10-14T10:04:42Z',
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14528671',
#    'address': None,
#    'phone': None,
#    'email': 'paula.amrl@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T10:51:00Z',
#    'updated_at': '2019-01-08T12:17:22Z'},
#   {'id': 'ddb572',
#    'name': 'Gulliver de Boer',
#    'firstname': 'Gulliver',
#    'lastname': 'de Boer',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '2nd Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14528672',
#    'address': None,
#    'phone': '+31612085780',
#    'email': 'gulif87@hotmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T10:51:04Z',
#    'updated_at': '2019-01-28T10:34:24Z'},
#   {'id': 'ddb582',
#    'name': 'Pieter Kouyzer',
#    'firstname': 'Pieter',
#    'lastname': 'Kouyzer',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14528688',
#    'address': None,
#    'phone': '+31(0)85 0020019',
#    'email': 'joris.braspenning@careerresult.nl',
#    'domain': None,
#    'created_at': '2016-09-05T10:52:07Z',
#    'updated_at': '2019-02-01T14:52:58Z'},
#   {'id': 'ddb9ca',
#    'name': 'Profiel Van Aris Koning',
#    'firstname': 'Profiel Van Aris',
#    'lastname': 'Koning',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '2nd Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14529784',
#    'address': None,
#    'phone': None,
#    'email': 'frank.kurstjens@jdriven.com',
#    'domain': None,
#    'created_at': '2016-09-05T11:49:31Z',
#    'updated_at': '2019-01-10T14:29:23Z'},
#   {'id': 'ddbfa2',
#    'name': 'Casper Rooker',
#    'firstname': 'Casper',
#    'lastname': 'Rooker',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Hired',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': '2016-09-23T14:20:02Z',
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14531280',
#    'address': None,
#    'phone': None,
#    'email': 'casper.rooker@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T13:07:18Z',
#    'updated_at': '2019-01-08T12:17:22Z'},
#   {'id': 'ddf173',
#    'name': 'Lennert Gijsen',
#    'firstname': 'Lennert',
#    'lastname': 'Gijsen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Hired',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': '2016-09-29T08:28:40Z',
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544033',
#    'address': None,
#    'phone': None,
#    'email': 'ellis@fahr-becker.nl',
#    'domain': None,
#    'created_at': '2016-09-05T18:40:42Z',
#    'updated_at': '2016-09-29T08:28:40Z'},
#   {'id': 'ddf20e',
#    'name': 'Serge Juchko',
#    'firstname': 'Serge',
#    'lastname': 'Juchko',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544188',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-05T18:48:10Z',
#    'updated_at': '2019-01-09T12:42:13Z'},
#   {'id': 'ddf485',
#    'name': 'Roel Theeuwen',
#    'firstname': 'Roel',
#    'lastname': 'Theeuwen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544819',
#    'address': None,
#    'phone': '0625642501',
#    'email': 'roel.theeuwen@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T19:17:50Z',
#    'updated_at': '2019-10-01T07:40:47Z'},
#   {'id': 'ddf4cd',
#    'name': 'Hasan Kurt',
#    'firstname': 'Hasan',
#    'lastname': 'Kurt',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544891',
#    'address': None,
#    'phone': '495 310 0184',
#    'email': 'ict@aatop.nl',
#    'domain': None,
#    'created_at': '2016-09-05T19:21:04Z',
#    'updated_at': '2016-09-23T13:13:16Z'},
#   {'id': 'ddf4d2',
#    'name': 'Bert de Vreugd',
#    'firstname': 'Bert',
#    'lastname': 'de Vreugd',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14544896',
#    'address': None,
#    'phone': None,
#    'email': 'bertdvreugd@msn.com',
#    'domain': None,
#    'created_at': '2016-09-05T19:21:16Z',
#    'updated_at': '2017-03-02T09:12:44Z'},
#   {'id': 'ddf7b4',
#    'name': 'Amin Ziarkash',
#    'firstname': 'Amin',
#    'lastname': 'Ziarkash',
#    'headline': 'Software Developer at Qualogy',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '2nd Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14545634',
#    'address': 'The Hague Area, Netherlands',
#    'phone': None,
#    'email': 'a.ziarkash@gmail.com',
#    'domain': 'search',
#    'created_at': '2016-09-05T19:57:55Z',
#    'updated_at': '2019-01-10T14:29:22Z'},
#   {'id': 'ddfcbd',
#    'name': 'Almar Schouten',
#    'firstname': 'Almar',
#    'lastname': 'Schouten',
#    'headline': 'Software Architect Frontend at Powerhouse Bv',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14546923',
#    'address': 'Utrecht Area, Netherlands',
#    'phone': None,
#    'email': 'almar.schouten@yahoo.com',
#    'domain': 'search',
#    'created_at': '2016-09-05T21:01:07Z',
#    'updated_at': '2019-01-08T12:17:22Z'},
#   {'id': 'ddfe84',
#    'name': 'Bastiaan Grisèl',
#    'firstname': 'Bastiaan',
#    'lastname': 'Grisèl',
#    'headline': 'Data Science & Technology MSc student',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14547378',
#    'address': 'Delft, Provincie Zuid-Holland, Nederland',
#    'phone': '+44 7 44 77 19 31 5',
#    'email': 'bastiaan.grisel@gmail.com',
#    'domain': 'search',
#    'created_at': '2016-09-05T21:24:09Z',
#    'updated_at': '2017-08-09T15:22:32Z'},
#   {'id': 'de4088',
#    'name': 'Thijs Immink',
#    'firstname': 'Thijs',
#    'lastname': 'Immink',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14564278',
#    'address': None,
#    'phone': None,
#    'email': 'r.out@java-professionals.nl',
#    'domain': None,
#    'created_at': '2016-09-06T12:13:16Z',
#    'updated_at': '2019-01-08T15:10:45Z'},
#   {'id': 'de4522',
#    'name': 'Robin Dronkers',
#    'firstname': 'Robin',
#    'lastname': 'Dronkers',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14565456',
#    'address': None,
#    'phone': None,
#    'email': 'robin.dronkers.werk@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-06T12:56:53Z',
#    'updated_at': '2017-12-29T12:36:12Z'},
#   {'id': 'de463d',
#    'name': 'Willem Ottenheijm',
#    'firstname': 'Willem',
#    'lastname': 'Ottenheijm',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14565739',
#    'address': None,
#    'phone': None,
#    'email': 'willemottenheijm@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-06T13:04:51Z',
#    'updated_at': '2017-12-29T12:36:11Z'},
#   {'id': 'de47a3',
#    'name': 'Stefan Tol',
#    'firstname': 'Tol',
#    'lastname': 'Stefan',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14566097',
#    'address': None,
#    'phone': '+31 (0)858882905',
#    'email': 'tolstefan@hotmail.com',
#    'domain': None,
#    'created_at': '2016-09-06T13:12:39Z',
#    'updated_at': '2016-09-07T09:26:35Z'},
#   {'id': 'de489d',
#    'name': 'Sieb Van Keppel',
#    'firstname': 'Sieb Van',
#    'lastname': 'Keppel',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'To schedule',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14566347',
#    'address': None,
#    'phone': None,
#    'email': 'sieb.van.keppel@mail.com',
#    'domain': None,
#    'created_at': '2016-09-06T13:20:26Z',
#    'updated_at': '2016-09-12T09:10:33Z'},
#   {'id': 'de53cd',
#    'name': 'Contracten recruiters',
#    'firstname': 'Contracten',
#    'lastname': 'recruiters',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14569211',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-06T14:28:19Z',
#    'updated_at': '2016-11-10T10:33:33Z'},
#   {'id': 'de5bfa',
#    'name': 'Jan Vries Lentsch',
#    'firstname': 'Jan',
#    'lastname': 'Vries Lentsch',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14571304',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-06T15:06:04Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'de5d64',
#    'name': 'Johannes Ransijn',
#    'firstname': 'Johannes',
#    'lastname': 'Ransijn',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14571666',
#    'address': None,
#    'phone': None,
#    'email': 'bram@careervalue.nl',
#    'domain': None,
#    'created_at': '2016-09-06T15:15:05Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'df6c94',
#    'name': 'Erwin Van Eyk',
#    'firstname': 'Erwin Van',
#    'lastname': 'Eyk',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14641090',
#    'address': None,
#    'phone': None,
#    'email': 'erwinvaneyk@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-08T08:02:15Z',
#    'updated_at': '2019-06-11T07:57:35Z'},
#   {'id': 'df77d7',
#    'name': 'Coskun Dag',
#    'firstname': 'Dag',
#    'lastname': 'Coskun',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14643973',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-08T09:45:57Z',
#    'updated_at': '2016-09-09T13:33:22Z'},
#   {'id': 'df78b9',
#    'name': 'Curriculum Vitae Kengyip Lee',
#    'firstname': 'Lee',
#    'lastname': 'Curriculum Vitae Kengyip',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14644199',
#    'address': None,
#    'phone': '+31 6 14563955',
#    'email': 'kengyiplee@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-08T09:56:05Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'df87cf',
#    'name': 'Yalda Mohammadian',
#    'firstname': 'Yalda',
#    'lastname': 'Mohammadian',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14648061',
#    'address': None,
#    'phone': '(020) 2401 401',
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-08T12:13:29Z',
#    'updated_at': '2018-06-02T07:41:16Z'},
#   {'id': 'df8812',
#    'name': 'Matthijs Brouns',
#    'firstname': 'Matthijs',
#    'lastname': 'Brouns',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14648128',
#    'address': None,
#    'phone': None,
#    'email': 'matthijs.brouns@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-08T12:16:40Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'dfaacc',
#    'name': 'Rutger de Graaf',
#    'firstname': 'Rutger',
#    'lastname': 'de Graaf',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'To schedule',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14657018',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-08T16:11:44Z',
#    'updated_at': '2017-12-29T12:36:11Z'},
#   {'id': 'dfaf18',
#    'name': 'Shoaib Amini',
#    'firstname': 'Shoaib',
#    'lastname': 'Amini',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14658118',
#    'address': None,
#    'phone': '23955-6900',
#    'email': 'renee.moerenhout+shoaibamini@jdriven.com',
#    'domain': None,
#    'created_at': '2016-09-08T16:42:36Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'e00269',
#    'name': 'Veli Aydin',
#    'firstname': 'Veli',
#    'lastname': 'Aydin',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14679447',
#    'address': None,
#    'phone': None,
#    'email': 'v_aydin@live.nl',
#    'domain': None,
#    'created_at': '2016-09-09T07:46:45Z',
#    'updated_at': '2016-09-20T07:05:08Z'},
#   {'id': 'e01304',
#    'name': 'Bram Neijt',
#    'firstname': 'Bram',
#    'lastname': 'Neijt',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Hired',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': '2016-10-04T11:02:37Z',
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14683698',
#    'address': None,
#    'phone': '+31612255344',
#    'email': 'bneijt@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-05T11:53:34Z',
#    'updated_at': '2016-10-04T11:02:37Z'},
#   {'id': 'e01384',
#    'name': 'Tim van Grieken',
#    'firstname': 'Tim Van',
#    'lastname': 'Grieken',
#    'headline': 'Web Analytics, Data Science and Social Psychology.',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14683826',
#    'address': 'Amsterdam, North Holland, Netherlands',
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-09T12:10:19Z',
#    'updated_at': '2016-09-29T08:21:05Z'},
#   {'id': 'e03bca',
#    'name': 'Dave Van Eijck',
#    'firstname': 'Dave Van',
#    'lastname': 'Eijck',
#    'headline': 'Senior Developer at 42.nl',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'To schedule',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14694136',
#    'address': 'Den Haag en omgeving, Nederland',
#    'phone': None,
#    'email': None,
#    'domain': 'search',
#    'created_at': '2016-09-09T18:16:42Z',
#    'updated_at': '2017-02-23T11:12:48Z'},
#   {'id': 'e096e5',
#    'name': 'Roy De Groot',
#    'firstname': 'Roy De',
#    'lastname': 'Groot',
#    'headline': 'Data Analytics Consultant & Data Science Analyst',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14717459',
#    'address': 'Utrecht en omgeving, Nederland',
#    'phone': None,
#    'email': None,
#    'domain': 'search',
#    'created_at': '2016-09-10T18:46:39Z',
#    'updated_at': '2019-03-05T11:17:22Z'},
#   {'id': 'e11c35',
#    'name': 'Mark Oost',
#    'firstname': 'Mark',
#    'lastname': 'Oost',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14751587',
#    'address': None,
#    'phone': '(020) 2401 401',
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-12T06:32:11Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'e12f8f',
#    'name': 'Uri Shimron',
#    'firstname': 'Uri',
#    'lastname': 'Shimron',
#    'headline': 'Senior data-analist at Coney',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14756541',
#    'address': 'The Hague, South Holland',
#    'phone': '+31888963850',
#    'email': 'shimron@localinfo.nl',
#    'domain': None,
#    'created_at': '2016-09-12T11:46:59Z',
#    'updated_at': '2017-12-29T12:36:10Z'},
#   {'id': 'e1cca6',
#    'name': 'Jeffrey Powell',
#    'firstname': 'Jeffrey',
#    'lastname': 'Powell',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '2nd Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14796756',
#    'address': None,
#    'phone': '+31622924942',
#    'email': 'farid@careervalue.nl',
#    'domain': None,
#    'created_at': '2016-09-13T13:26:27Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'e23fde',
#    'name': 'Bert Carsouw',
#    'firstname': 'Bert',
#    'lastname': 'Carsouw',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14826252',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-14T06:09:40Z',
#    'updated_at': '2017-12-12T14:29:28Z'},
#   {'id': 'e27389',
#    'name': 'Marc Huls',
#    'firstname': 'Marc',
#    'lastname': 'Huls',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14839479',
#    'address': None,
#    'phone': None,
#    'email': 'jvandiest@spilberg.nl',
#    'domain': None,
#    'created_at': '2016-09-14T15:35:29Z',
#    'updated_at': '2019-01-08T12:17:21Z'},
#   {'id': 'e2d0e6',
#    'name': 'Pim Schellart',
#    'firstname': 'Pim',
#    'lastname': 'Schellart',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Shortlisted',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14863380',
#    'address': None,
#    'phone': '+1 (609) 356-4519',
#    'email': 'p.schellart@princeton.edu',
#    'domain': None,
#    'created_at': '2016-09-15T08:07:44Z',
#    'updated_at': '2019-01-15T10:35:52Z'},
#   {'id': 'e2d1ee',
#    'name': 'Sander Kerkdijk',
#    'firstname': 'Sander',
#    'lastname': 'Kerkdijk',
#    'headline': 'Data Scientist @ Aneto BV Bunnink',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14863644',
#    'address': None,
#    'phone': '06-22 55 71 92',
#    'email': 'sander.kerkdijk@aneto.nl',
#    'domain': None,
#    'created_at': '2016-09-15T08:24:05Z',
#    'updated_at': '2019-09-20T13:20:26Z'},
#   {'id': 'e2d3f3',
#    'name': 'Kia Eisinga',
#    'firstname': 'Kia',
#    'lastname': 'Eisinga',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14864161',
#    'address': None,
#    'phone': None,
#    'email': 'kiaeisinga@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-15T08:48:42Z',
#    'updated_at': '2019-08-28T13:18:31Z'},
#   {'id': 'e2d4ac',
#    'name': 'Kaitlin Nadson',
#    'firstname': 'Kaitlin',
#    'lastname': 'Nadson',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14864346',
#    'address': None,
#    'phone': '+31 (0)6 136 294 81',
#    'email': 'kaitlin.nadson@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-15T08:57:58Z',
#    'updated_at': '2016-09-26T13:00:44Z'},
#   {'id': 'e2d5c4',
#    'name': 'Juan Adriaanse',
#    'firstname': 'Juan',
#    'lastname': 'Adriaanse',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'To schedule',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/14864626',
#    'address': None,
#    'phone': '285 97 272',
#    'email': 'adriaanse.juan@gmail.nl',
#    'domain': None,
#    'created_at': '2016-09-15T09:15:52Z',
#    'updated_at': '2016-10-17T13:43:13Z'},
#   {'id': 'e2d75b',
#    'name': 'Mar Maykel Vink',
#    'firstname': 'Mar',
#    'lastname': 'Maykel Vink',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14865033',
#    'address': None,
#    'phone': None,
#    'email': 'maykel@maykelvink.nl',
#    'domain': None,
#    'created_at': '2016-09-15T09:31:28Z',
#    'updated_at': '2019-01-08T12:17:20Z'},
#   {'id': 'e2e573',
#    'name': 'Lucas Maasse',
#    'firstname': 'Lucas',
#    'lastname': 'Maasse',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14868641',
#    'address': None,
#    'phone': '0655967587',
#    'email': 'lucasmaasse@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-15T12:42:16Z',
#    'updated_at': '2019-06-03T07:59:29Z'},
#   {'id': 'e3016e',
#    'name': 'Benjamin Van Den Akker',
#    'firstname': 'Benjamin Van Den',
#    'lastname': 'Akker',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14875804',
#    'address': None,
#    'phone': '06 44872734',
#    'email': 'benjaminvandenakker@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-15T16:18:29Z',
#    'updated_at': '2019-01-08T12:17:20Z'},
#   {'id': 'e36bc6',
#    'name': 'Dana Bˇalibanu',
#    'firstname': 'Dana',
#    'lastname': 'Bˇalibanu',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/14903028',
#    'address': None,
#    'phone': '+31 (627) 206 495',
#    'email': 'danabalibanu@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-16T13:47:44Z',
#    'updated_at': '2019-01-10T14:23:30Z'},
#   {'id': 'e37c6f',
#    'name': 'Mark Vervuurt',
#    'firstname': 'Mark',
#    'lastname': 'Vervuurt',
#    'headline': 'Senior Big Data / Java Consultant at Capgemini',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14907293',
#    'address': 'Utrecht, Netherlands',
#    'phone': None,
#    'email': 'm.a.vervuurt@gmail.com',
#    'domain': 'search',
#    'created_at': '2016-09-16T16:06:43Z',
#    'updated_at': '2019-02-25T08:22:48Z'},
#   {'id': 'e3c572',
#    'name': 'Pearl Roman',
#    'firstname': 'Pearl',
#    'lastname': 'Roman',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/14925984',
#    'address': None,
#    'phone': '+31619424969',
#    'email': 'pearlroman@hotmail.com',
#    'domain': None,
#    'created_at': '2016-09-17T09:38:43Z',
#    'updated_at': '2019-01-08T12:17:20Z'},
#   {'id': 'e48b5d',
#    'name': 'Matthijs van der Kroon',
#    'firstname': 'Matthijs Van Der',
#    'lastname': 'Kroon',
#    'headline': 'Data Scientist at RTL Nederland',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14976651',
#    'address': 'San Francisco, California, United States',
#    'phone': None,
#    'email': 'mvdkroon@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-19T15:46:27Z',
#    'updated_at': '2017-12-29T12:36:09Z'},
#   {'id': 'e48ca1',
#    'name': 'Anthony Potappel',
#    'firstname': 'Anthony',
#    'lastname': 'Potappel',
#    'headline': 'Big Data enthusiast at Vancis | Cloud | Software Defined * | Automation | Hadoop | OpenStack | Linux',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F17EA1F924', 'title': 'Big Data Architect'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331678/candidates/14976975',
#    'address': 'Amsterdam, North Holland, Netherlands',
#    'phone': None,
#    'email': 'apotappel@itslogic.nl',
#    'domain': None,
#    'created_at': '2016-09-19T15:53:17Z',
#    'updated_at': '2017-03-01T09:47:22Z'},
#   {'id': 'e48dcf',
#    'name': 'Sietse T. Au',
#    'firstname': 'Sietse T',
#    'lastname': 'Au',
#    'headline': 'Software Engineer',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F17EA1F924', 'title': 'Big Data Architect'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331678/candidates/14977277',
#    'address': 'Den Haag en omgeving, Nederland',
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-19T16:00:41Z',
#    'updated_at': '2017-12-29T12:36:09Z'},
#   {'id': 'e48e52',
#    'name': 'Joost Heijkoop',
#    'firstname': 'Joost',
#    'lastname': 'Heijkoop',
#    'headline': 'Software Consultant / Full Stack Developer at DHL',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/14977408',
#    'address': 'Amsterdam, Netherlands',
#    'phone': None,
#    'email': 'leipie@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-19T16:03:54Z',
#    'updated_at': '2017-12-29T12:36:09Z'},
#   {'id': 'e4f7dd',
#    'name': 'Thierry Quirijn Mentzel',
#    'firstname': 'Thierry',
#    'lastname': 'Quirijn Mentzel',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15004427',
#    'address': None,
#    'phone': '+31654724248',
#    'email': 't.q.mentzel@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-20T07:34:14Z',
#    'updated_at': '2017-12-29T12:36:09Z'},
#   {'id': 'e50701',
#    'name': 'Wibo Pipping',
#    'firstname': 'Wibo',
#    'lastname': 'Pipping',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15008303',
#    'address': None,
#    'phone': '+316 30 11 97 10',
#    'email': 'wibo.pipping@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-20T10:53:58Z',
#    'updated_at': '2017-12-29T12:36:09Z'},
#   {'id': 'e51018',
#    'name': 'Dimitri Pater',
#    'firstname': 'Dimitri',
#    'lastname': 'Pater',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15010630',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-20T12:38:29Z',
#    'updated_at': '2019-01-08T12:17:19Z'},
#   {'id': 'e58576',
#    'name': 'Gerard Simons',
#    'firstname': 'Gerard',
#    'lastname': 'Simons',
#    'headline': 'Data Scientist at Qualogy',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15040676',
#    'address': 'Rotterdam, South Holland, Netherlands',
#    'phone': '06 538 606 42',
#    'email': 'sjrasimons@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-21T06:21:00Z',
#    'updated_at': '2019-01-10T14:22:20Z'},
#   {'id': 'e5a36a',
#    'name': 'Ir Joost Van Veen',
#    'firstname': 'Ir Joost Van',
#    'lastname': 'Veen',
#    'headline': 'gpa',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15048344',
#    'address': 'Netherlands',
#    'phone': '0613387450',
#    'email': 'gpabna@icloud.com',
#    'domain': None,
#    'created_at': '2016-09-21T12:31:11Z',
#    'updated_at': '2017-12-29T12:36:08Z'},
#   {'id': 'e62144',
#    'name': 'Jeroen Vlek',
#    'firstname': 'Jeroen',
#    'lastname': 'Vlek',
#    'headline': 'Anchormen',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15080562',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-22T07:39:40Z',
#    'updated_at': '2017-12-29T12:36:08Z'},
#   {'id': 'e625d1',
#    'name': 'Ian FitzPatrick',
#    'firstname': 'Ian',
#    'lastname': 'Fitzpatrick',
#    'headline': 'Post Doctoral researcher: Neuroscience of language and bilingualism',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15081727',
#    'address': 'Nijmegen, Gelderland, Netherlands',
#    'phone': None,
#    'email': 'ian@ianfitzpatrick.eu',
#    'domain': None,
#    'created_at': '2016-09-22T08:44:55Z',
#    'updated_at': '2016-11-22T09:48:46Z'},
#   {'id': 'e626f8',
#    'name': 'Hessel Miedema',
#    'firstname': 'Hessel',
#    'lastname': 'Miedema',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F17EA1F924', 'title': 'Big Data Architect'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331678/candidates/15082022',
#    'address': None,
#    'phone': '+44 7478 945 418',
#    'email': 'hessel.miedema@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-22T08:59:56Z',
#    'updated_at': '2019-01-08T12:17:19Z'},
#   {'id': 'e638d2',
#    'name': 'Fabian Voorter',
#    'firstname': 'Fabian',
#    'lastname': 'Voorter',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '8176464B66',
#     'title': 'Front-End Developer (Divotion)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/340395/candidates/15086592',
#    'address': None,
#    'phone': None,
#    'email': 'e.wagemaker@java-professionals.nl',
#    'domain': None,
#    'created_at': '2016-09-22T12:39:16Z',
#    'updated_at': '2019-06-13T07:27:56Z'},
#   {'id': 'e66728',
#    'name': 'Front-End Developer',
#    'firstname': 'Front-End',
#    'lastname': 'Developer',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '8176464B66',
#     'title': 'Front-End Developer (Divotion)'},
#    'stage': 'To schedule',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/340395/candidates/15098454',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-22T18:26:33Z',
#    'updated_at': '2016-10-06T15:46:05Z'},
#   {'id': 'e67a26',
#    'name': 'Saskia Koldijk',
#    'firstname': 'Saskia',
#    'lastname': 'Koldijk',
#    'headline': 'Cognitive Artificial Intelligence Expert bij Sense Health BV',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15103316',
#    'address': 'Utrecht Area, Netherlands',
#    'phone': None,
#    'email': None,
#    'domain': 'search',
#    'created_at': '2016-09-22T20:55:33Z',
#    'updated_at': '2017-12-29T12:36:08Z'},
#   {'id': 'e67b0f',
#    'name': 'Roland De Boo',
#    'firstname': 'Roland De',
#    'lastname': 'Boo',
#    'headline': 'Software Architect | Java, Cloud, Sensor Networks, Event Processing',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F17EA1F924', 'title': 'Big Data Architect'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331678/candidates/15103549',
#    'address': 'Rotterdam, South Holland, Netherlands',
#    'phone': None,
#    'email': 'rolanddeboo@gmail.com',
#    'domain': 'search',
#    'created_at': '2016-09-22T21:04:05Z',
#    'updated_at': '2017-12-29T12:36:08Z'},
#   {'id': 'e67bb3',
#    'name': 'Chris Blom',
#    'firstname': 'Chris',
#    'lastname': 'Blom',
#    'headline': 'Software Engineer at ADGOJI',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Shortlisted',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15103713',
#    'address': None,
#    'phone': None,
#    'email': 'chrisblom@chrisblom.net',
#    'domain': 'unknown',
#    'created_at': '2016-09-22T21:10:22Z',
#    'updated_at': '2019-01-14T14:53:40Z'},
#   {'id': 'e67d9a',
#    'name': 'Christopher Tunnell',
#    'firstname': 'Christopher',
#    'lastname': 'Tunnell',
#    'headline': 'Physicist and founder Snooty Analytics',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15104200',
#    'address': 'Amsterdam, North Holland, Netherlands',
#    'phone': None,
#    'email': 'ctunnell@nikhef.nl',
#    'domain': 'search',
#    'created_at': '2016-09-22T21:21:55Z',
#    'updated_at': '2019-01-08T12:17:19Z'},
#   {'id': 'e6af5b',
#    'name': 'Rob Driessen',
#    'firstname': 'Rob',
#    'lastname': 'Driessen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
# ...
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/15208063',
#    'address': None,
#    'phone': None,
#    'email': 'nmdrenard@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-26T18:22:54Z',
#    'updated_at': '2019-01-10T13:01:52Z'},
#   {'id': 'e86ad3',
#    'name': 'Jorden Schrama',
#    'firstname': 'Jorden',
#    'lastname': 'Schrama',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '9882E4C0EA', 'title': 'Java Developer (JDriven)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331510/candidates/15230465',
#    'address': None,
#    'phone': '+31628198643',
#    'email': 'jordenschrama@hotmail.com',
#    'domain': None,
#    'created_at': '2016-09-12T15:00:54Z',
#    'updated_at': '2019-06-11T17:06:08Z'},
#   {'id': 'e86bc0',
#    'name': 'Charalampos Sarantopoulos',
#    'firstname': 'Charalampos',
#    'lastname': 'Sarantopoulos',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15230702',
#    'address': None,
#    'phone': '(+31) 0647401851',
#    'email': 'charalampos.sarantopoulos@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-27T08:51:43Z',
#    'updated_at': '2017-02-13T11:32:16Z'},
#   {'id': 'e875d1',
#    'name': 'Roel Nieuwenhuizen',
#    'firstname': 'Roel',
#    'lastname': 'Nieuwenhuizen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/15233279',
#    'address': None,
#    'phone': None,
#    'email': 'jvandiest@spilberg.nl',
#    'domain': None,
#    'created_at': '2016-09-27T10:55:12Z',
#    'updated_at': '2019-01-08T12:17:18Z'},
#   {'id': 'e88844',
#    'name': 'Anton Bossenbroek',
#    'firstname': 'Anton',
#    'lastname': 'Bossenbroek',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15238002',
#    'address': None,
#    'phone': '+1 646 919 6539',
#    'email': 'anton.bossenbroek@me.com',
#    'domain': None,
#    'created_at': '2016-09-27T13:49:12Z',
#    'updated_at': '2018-05-08T10:50:39Z'},
#   {'id': 'e991c1',
#    'name': 'Boris Reuderink',
#    'firstname': 'Boris',
#    'lastname': 'Reuderink',
#    'headline': 'Machine Learning Consultant at Cortext',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15305967',
#    'address': 'Utrecht, Netherlands',
#    'phone': None,
#    'email': 'b.reuderink@gmail.com',
#    'domain': 'search',
#    'created_at': '2016-09-29T06:35:08Z',
#    'updated_at': '2017-07-06T08:23:43Z'},
#   {'id': 'e991e5',
#    'name': 'Sjoerd de Haan',
#    'firstname': 'Sjoerd',
#    'lastname': 'de Haan',
#    'headline': 'Machine learning devoper at ING',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15306003',
#    'address': 'Groningen en omgeving, Nederland',
#    'phone': None,
#    'email': 'sjdh@xs4all.nl',
#    'domain': 'search',
#    'created_at': '2016-09-29T06:37:31Z',
#    'updated_at': '2016-11-28T06:47:51Z'},
#   {'id': 'e99a03',
#    'name': 'Laurens Koppenol',
#    'firstname': 'Laurens',
#    'lastname': 'Koppenol',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15308081',
#    'address': None,
#    'phone': '06-42145808',
#    'email': 'renee.moerenhout@bigdatarepublic.nl',
#    'domain': None,
#    'created_at': '2016-09-29T08:58:56Z',
#    'updated_at': '2019-01-08T12:17:18Z'},
#   {'id': 'e9a3af',
#    'name': 'Daniel Profiel',
#    'firstname': 'Daniel',
#    'lastname': 'Profiel',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15310557',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-29T11:23:29Z',
#    'updated_at': '2016-12-06T13:08:17Z'},
#   {'id': 'e9a3b0',
#    'name': 'Michel Capelle',
#    'firstname': 'Michel',
#    'lastname': 'Capelle',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15310558',
#    'address': None,
#    'phone': None,
#    'email': 'michel@michelcapelle.nl',
#    'domain': None,
#    'created_at': '2016-09-29T11:23:30Z',
#    'updated_at': '2019-01-08T12:17:18Z'},
#   {'id': 'ea0e8f',
#    'name': 'Simon van der Zon',
#    'firstname': 'Simon',
#    'lastname': 'van der Zon',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Talentpool',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15337917',
#    'address': None,
#    'phone': '+31611799349',
#    'email': 'simonvanderzon@hotmail.com',
#    'domain': None,
#    'created_at': '2016-09-30T06:43:02Z',
#    'updated_at': '2019-01-10T14:22:20Z'},
#   {'id': 'ea1045',
#    'name': 'Julian Vos',
#    'firstname': 'Julian',
#    'lastname': 'Vos',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/15338355',
#    'address': None,
#    'phone': None,
#    'email': 'julianvosje@gmail.com',
#    'domain': None,
#    'created_at': '2016-09-30T07:23:54Z',
#    'updated_at': '2017-12-29T12:36:06Z'},
#   {'id': 'ea178d',
#    'name': 'Jeroen Dalhuisen',
#    'firstname': 'Jeroen',
#    'lastname': 'Dalhuisen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15340219',
#    'address': None,
#    'phone': '+31 6 24890046',
#    'email': 'jdalhuisen@hotmail.com',
#    'domain': None,
#    'created_at': '2016-09-30T09:51:15Z',
#    'updated_at': '2019-01-08T12:17:18Z'},
#   {'id': 'ea22b7',
#    'name': 'Rick Slangen',
#    'firstname': 'Rick',
#    'lastname': 'Slangen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15343077',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-09-30T12:39:51Z',
#    'updated_at': '2019-01-08T12:17:18Z'},
#   {'id': 'eacf37',
#    'name': 'Daan Debie',
#    'firstname': 'Daan',
#    'lastname': 'Debie',
#    'headline': 'Freelance Software Engineer / Data Engineer / Firestarter at Joy in Coding',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F17EA1F924', 'title': 'Big Data Architect'},
#    'stage': 'Applied',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331678/candidates/15387237',
#    'address': 'Amsterdam, North Holland, Netherlands',
#    'phone': None,
#    'email': 'debie.daan@gmail.com',
#    'domain': 'search',
#    'created_at': '2016-10-02T15:26:22Z',
#    'updated_at': '2017-12-29T12:36:06Z'},
#   {'id': 'eacfad',
#    'name': 'Bart Jeukendrup',
#    'firstname': 'Bart',
#    'lastname': 'Jeukendrup',
#    'headline': 'Founder at Infty - Data scientist, software architect',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15387355',
#    'address': 'Amsterdam Area, Netherlands',
#    'phone': None,
#    'email': 'bartjeukendrup@elooglobal.com',
#    'domain': 'search',
#    'created_at': '2016-10-02T15:32:30Z',
#    'updated_at': '2017-12-29T12:36:06Z'},
#   {'id': 'eacfe0',
#    'name': 'Paul Bormans',
#    'firstname': 'Paul',
#    'lastname': 'Bormans',
#    'headline': 'oce technologies',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15387406',
#    'address': 'Eindhoven Area, Netherlands',
#    'phone': None,
#    'email': 'paul.bormans@oce.com',
#    'domain': 'search',
#    'created_at': '2016-10-02T15:35:44Z',
#    'updated_at': '2019-01-08T12:17:18Z'},
#   {'id': 'ead014',
#    'name': 'Michiel Moonen',
#    'firstname': 'Michiel',
#    'lastname': 'Moonen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Applied',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15387458',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': 'unknown',
#    'created_at': '2016-10-02T15:38:58Z',
#    'updated_at': '2019-02-25T08:29:18Z'},
#   {'id': 'ead061',
#    'name': 'Karsten Meinster',
#    'firstname': 'Karsten',
#    'lastname': 'Meinster',
#    'headline': 'Mission Critical Engineer @ Schuberg Philis',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F17EA1F924', 'title': 'Big Data Architect'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331678/candidates/15387535',
#    'address': 'Den Haag en omgeving, Nederland',
#    'phone': None,
#    'email': None,
#    'domain': 'search',
#    'created_at': '2016-10-02T15:42:48Z',
#    'updated_at': '2017-03-14T08:44:50Z'},
#   {'id': 'eb1555',
#    'name': 'Hassane Barre',
#    'firstname': 'Hassane',
#    'lastname': 'Barre',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/15405187',
#    'address': None,
#    'phone': '+31 (0)858882905',
#    'email': 'hasbarre@gmail.com',
#    'domain': None,
#    'created_at': '2016-10-03T08:58:35Z',
#    'updated_at': '2017-12-29T12:36:05Z'},
#   {'id': 'eb2cf8',
#    'name': 'Gebrekirstos G Gebremeskel',
#    'firstname': 'Gebrekirstos G',
#    'lastname': 'Gebremeskel',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15411238',
#    'address': None,
#    'phone': '+31647270950',
#    'email': 'gebre@cwi.nl',
#    'domain': None,
#    'created_at': '2016-10-03T13:19:34Z',
#    'updated_at': '2019-01-08T12:17:18Z'},
#   {'id': 'eb4afd',
#    'name': 'Tim van Elteren',
#    'firstname': 'Tim',
#    'lastname': 'van Elteren',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/15418923',
#    'address': None,
#    'phone': None,
#    'email': 'ovidiu.terinte@astburymarsden.com',
#    'domain': None,
#    'created_at': '2016-10-03T16:37:39Z',
#    'updated_at': '2017-08-28T11:12:38Z'},
#   {'id': 'ebb4b0',
#    'name': 'Danielle McCool',
#    'firstname': 'Danielle',
#    'lastname': 'McCool',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/15445982',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2016-10-04T08:40:40Z',
#    'updated_at': '2019-01-08T12:17:17Z'}],
#  'paging': {'next': 'https://jdriven.workable.com/spi/v3/candidates?limit=100&since_id=ebb4b1'}}

# %%
#requests.get(url+'candidates/48384b3'+'.json', headers=headers).json()
#requests.get(url+'candidates/48384b3/activities'+'.json', headers=headers).json()['activities']
#section = 'events?'
#events = requests.get(url+section+'.json', headers=headers).json()

#section = 'jobs/A8C5321F60/activities'
#j = requests.get(url+section+'.json', headers=headers).json()
