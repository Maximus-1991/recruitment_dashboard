# %%
# TO DO
# Check why max_id doesnt work

# Check if names have multiple entries
# Retrieve all keys in dictionary that do not contain

# %%
# Workable API
import requests
import pandas as pd
import datetime
from datetime import date


headers={'Authorization': 'Bearer 229aa3876e4fc4447460a13da7f57d1be4111202e1d56d4d0231fb932c1e7cd1'}
url = 'https://jdriven.workable.com/spi/v3/'

#r_jobs = requests.get(url+'jobs.json', headers=headers)
#r_stages = requests.get(url+'stages.json', headers=headers)
#r_cand = requests.get(url+'candidates.json', headers=headers)

#By default results are limited to 50. The limit can by updated via the request parameter limit
#The value specified cannot be more than 100.
#cand_dict['paging']
#{'next': 'https://jdriven.workable.com/spi/v3/candidates?limit=50&since_id=e48b5d'}

#since_id: string. Returns results with an ID greater than or equal to the specified ID

#paging indicates what the next webpage is. 
# Since_id indicates that the requested data is taken before the since_ID
# In other words, the next page starts with since_D
# {'next': 'https://jdriven.workable.com/spi/v3/candidates?limit=100&since_id=f36d27'}
# Limit indicates the number of IDs retrieved before the since_ID

#max_id
# Get max_id, limit=100 to get the 100 latest entries
# Then use the first entry of that request for the following request, using since_Id=first entry of the first request

# I want to retrieve the last ID
# Maybe can retrieve using created_after and setting this to last week. If it cannot find anything, using another week back in time
#'https://jdriven.workable.com/spi/v3/candidates?limit=100&created_after=2019-09-01T13:29:49Z}'

#Timestamp parameters input format
#Supported input formats for the timestamp fields created_after & updated_after are:
#ISO8601 e.g. 20150708T115616Z
#Unix time (e.g. 1436356721)

# %%
from collections import Sequence
from itertools import chain, count, tee

def locate_element(data,look_up_elem):
    '''
    Function to locate the exact location of a an element in a data structure
    '''
    data_orig = data
    loc_list = []
    
    #### Step 1: Create loop: while look_up_elem not in loc_list
    while look_up_elem not in loc_list:

        data = data_orig
        if loc_list != []:
            for location in loc_list:
                data = data[location]     
        
        #### Step 2: Create loop for each element in data. This element needs to be appended to loc_list if element is found in (sub-levels of) this element
        # Combine step 4 and 5 in one function. Function is to flatten the data and check if look_up_elem is present in data. If element is found, return loc_list
        def check_branche(data):
                    #### Step 2: Check if look_up_element is present on 1st level of data
            if look_up_elem in data:
                loc_list.append(look_up_elem)
                return loc_list

            #### Step 3: If element not present on 1st level, filter out strings and integers from data. Method is different for different data types
            # Note: data_tuple = () (will be problematic, as you cannot append elements to a tuple). We may be able to add items from tuple to list as tuple is also a Sequence

            # Define data_elements
            if type(data)==dict: 
                data_elements = list(data.keys())
            elif type(data)==list: 
                data_elements = list(range(len(data)))
            # elif type(data)==tuple: 
                #data_elements = list(range(len(data)))

            else:
                return "Element not present"
                      
            for element in data_elements:

                data_to_check = data[element]

                # Define data_dict, data_list and data_tuple
                if type(data_to_check)==dict:
                    data_dict = data_to_check
                    data_list = []
                    data_tuple = ()
                elif type(data_to_check)==list:
                    data_dict = {}
                    data_list = data_to_check
                    data_tuple = ()
                elif type(data_to_check)==tuple:
                    data_dict = {}
                    data_list = []
                    data_tuple = data_to_check
                elif type(data_to_check)!=dict and type(data_to_check)!=list and type(data_to_check)!=tuple:
                    continue
                else:
                    return "Error"

                #### Step 5: Enter while loop (is within the for loop of step 4). From the filtered data obtained in step 3, divide the different elements into its data type. Then, flatten type(data) data type first and then the other two data types
                # When look_up_elem is found, append element to loc_list and return loc_list
                while data_dict != {} or data_list != [] or data_tuple !=():
                    # Flatten dictionary and check if element is present on any of the levels and add list elements to data_list
                    # After first round, if any elements were added to data_dict, go through these added elements
                    while data_dict != {}:
                        if look_up_elem in data_dict:
                            loc_list.append(element)
                            return 
                            
                        data_dict_temp = {}
                        # Filter the elements in data_dict
                        for key,value in iter(data_dict.items()):
                            if type(value)==dict:
                                data_dict_temp.update(value)
                            elif type(value)==list:
                                data_list.append(value)
                            #elif type(value)==tuple:
                            #    test_tuple
                            # to check if tuple is also a sequence, can also use chain(element) for this
                            else:
                                "Element is string or integer"
                        data_dict = data_dict_temp

                    # After data_dict is (temporarily) exhausted, go through data_list
                    while data_list != []:
                        if look_up_elem in data_list:
                            loc_list.append(element)
                            return loc_list

                        data_list_temp = []
                        # Filter the elements in data_dict
                        for item in data_list:
                            if type(item)==dict:
                                data_dict.update(item)
                            elif type(item)==list:
                                for i in item:
                                    data_list_temp.append(i)
                            else:
                                "Element is string or integer"
                        data_list = data_list_temp

                    # After data_list is (temporarily) exhausted, go through data_tuple
                    #while data_tuple !=():
                        # Flatten tuple, check if element is present on any of the levels and add dictionary and list elements to data_dict or data_list
                        #pass

            if look_up_elem not in loc_list:
                return "Element not Found"
        check_branche(data)
    
    return loc_list
# Out:
# C:\Users\Maarten\Anaconda3\envs\ams\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   """Entry point for launching an IPython kernel.

# %%
import copy
def change_name_duplicate_keys(d):
    d_no_dupes = copy.deepcopy(d)
    all_keys = {}
    all_keys_temp = {}
    list_check = []
    duplicate_remover_dict = d_no_dupes  
    while duplicate_remover_dict !={}:
        dict_temp = {}
        no_dupes = 0
        for key,value in iter(duplicate_remover_dict.items()):
            if type(value)==dict and value !={}:
                for k,v in value.items():
                    if k in dict_temp or k in all_keys: 
                        key_to_replace = k
                        key_loc = locate_element(duplicate_remover_dict,key_to_replace)
                        key_new = key_to_replace+'_'+str(key_loc[len(key_loc)-2])
                        replacement_dict = duplicate_remover_dict
                        for key in key_loc[:len(key_loc)-1]:
                            replacement_dict = replacement_dict[key]
                        replacement_dict[key_new] = replacement_dict.pop(key_to_replace)
                        no_dupes = 1
                    else:
                        all_keys_temp.update({k:v})
                if no_dupes ==1:
                    all_keys_temp = {}
                    break
                else:
                    dict_temp.update(value)
            
            elif type(value)==list and value != []:
                if all(type(item) == dict for item in value):
                    for item in value:
                        for k,v in item.items():
                            if k in all_keys or k in dict_temp:
                                key_to_replace = k
                                key_loc = locate_element(duplicate_remover_dict,key_to_replace)
                                key_new = key_to_replace+'_'+str(key_loc[len(key_loc)-2])
                                replacement_dict = duplicate_remover_dict
                                for key in key_loc[:len(key_loc)-1]:
                                    replacement_dict = replacement_dict[key]
                                replacement_dict[key_new] = replacement_dict.pop(key_to_replace)
                                no_dupes = 1
                            else:
                                all_keys_temp.update({k:v})
                        if no_dupes ==1:
                            all_keys_temp = {}
                            break
                        else:
                            dict_temp.update(item)
                else:
                    all_keys_temp.update({key:value})
                    for i in value:
                        list_check.append(i)
                    # Append any dict in value (list) to dict_temp.update 
                    while list_check != []:
                        list_temp = []
                        for item in list_check:
                            if type(item)==dict:
                                # Check if item not duplicate 
                                for k,v in item.items():
                                    if k in all_keys or k in dict_temp:
                                        key_to_replace = k
                                        key_loc = locate_element(duplicate_remover_dict,key_to_replace)
                                        key_new = key_to_replace+'_'+str(key_loc[len(key_loc)-2])
                                        replacement_dict = duplicate_remover_dict
                                        for key in key_loc[:len(key_loc)-1]:
                                            replacement_dict = replacement_dict[key]
                                        replacement_dict[key_new] = replacement_dict.pop(key_to_replace)
                                        no_dupes = 1
                                    else:
                                        all_keys_temp.update({k:v})
                                if no_dupes == 1:
                                    all_keys_temp = {}
                                    break
                                else:
                                    dict_temp.update(item)
                            elif type(item)==list:
                                for i in item:
                                    list_temp.append(i)
                            else:
                                continue
                        list_check = list_temp
                              
            else:
                if key in all_keys or key in dict_temp: 
                    key_to_replace = key
                    key_loc = locate_element(d_no_dupes,key_to_replace) #You use d_no_dupes because duplicate_remover dict has moved 1 level down i.e. key will not be in there anymore
                    type_to_check = d_no_dupes
                    for key in key_loc[:len(key_loc)-1]:
                        type_to_check = type_to_check[key]
                    if len(key_loc) == 1 or type(type_to_check) !=dict:
                        key_new = key_to_replace+'_'+str(key_loc[len(key_loc)-2])
                        replacement_dict = d_no_dupes
                        #You use d_no_dupes because duplicate_remover dict has moved 1 level down i.e. key will not be in there anymore
                        if len(key_loc)>1:
                            for key in key_loc[:len(key_loc)-1]:
                                replacement_dict = replacement_dict[key]
                        replacement_dict[key_new] = replacement_dict.pop(key_to_replace)
                        duplicate_remover_dict.pop(key)
                        no_dupes = 1
                        all_keys_temp = {}
                        break
                else:
                    all_keys_temp.update({key:value})
        if no_dupes ==0:
            duplicate_remover_dict = dict_temp
            all_keys.update(all_keys_temp)
    return d_no_dupes

# %%
# Create data dictionary
key_list = [
    'id',
    'name',
    'firstname',
    'lastname',
    'headline',
    'subdomain', 
#    'name', need to rename using retrieve key function
    'shortcode',
    'title',
    'stage',
    'disqualified',
    'disqualification_reason',
    'hired_at',
    'sourced',
    'profile_url',
    'address',
    'phone',
    'email',
    'domain',
    'created_at',
    'updated_at',
]
# Create DataFrame column labels
df_dict = {}
for key in key_list:
    df_dict[key]=[]

# %%
# Get latest entry:

section = 'candidates?'
limit='100'

d = datetime.datetime.today().isoformat()
r_last_cand = requests.get(url+section+'limit='+limit+'&created_after='+d+'.json', headers=headers)
while len(r_last_cand.json()['candidates'])==0:
    d = (datetime.datetime.today() - datetime.timedelta(days=1)).isoformat()
    r_last_cand = requests.get('https://jdriven.workable.com/spi/v3/candidates?limit=100&created_after='+d+'.json', headers=headers)
last_id = r_last_cand.json()['candidates'][-1]['id']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-17dd115a0368> in <module>
#       6 d = datetime.datetime.today().isoformat()
#       7 r_last_cand = requests.get(url+section+'limit='+limit+'&created_after='+d+'.json', headers=headers)
# ----> 8 while len(r_last_cand.json()['candidates'])==0:
#       9     d = (datetime.datetime.today() - datetime.timedelta(days=1)).isoformat()
#      10     r_last_cand = requests.get('https://jdriven.workable.com/spi/v3/candidates?limit=100&created_after='+d+'.json', headers=headers)
#
# KeyError: 'candidates'

# %%
r = requests.get(url+section+'limit='+limit+'&created_after=2019-09-01T10:10:10Z.json', headers=headers)

# %%
d
# Out:
# '2019-09-14T13:30:10.346962'

# %%
r.json()
# Out:
# {'candidates': [{'id': '46949e5',
#    'name': 'Fatima Arraye',
#    'firstname': 'Fatima',
#    'lastname': 'Arraye',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74007827',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-02T07:55:58Z',
#    'updated_at': '2019-09-03T08:52:56Z'},
#   {'id': '4697faa',
#    'name': 'Big Data Team Lead',
#    'firstname': 'Big',
#    'lastname': 'Data Team Lead',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'To schedule',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/74021592',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-02T11:09:31Z',
#    'updated_at': '2019-09-11T07:40:24Z'},
#   {'id': '469978c',
#    'name': 'Marjolein Smits',
#    'firstname': 'Marjolein',
#    'lastname': 'Smits',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74027706',
#    'address': None,
#    'phone': '0646038646',
#    'email': 'mnm.smits@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-02T13:01:05Z',
#    'updated_at': '2019-09-06T14:48:33Z'},
#   {'id': '4699f6e',
#    'name': 'Christianne Wisse',
#    'firstname': 'Christianne',
#    'lastname': 'Wisse',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': '1st Interview',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74029724',
#    'address': None,
#    'phone': '0631581786',
#    'email': 'christiannewisse@hotmail.com',
#    'domain': 'linkedin.com',
#    'created_at': '2019-09-02T13:33:46Z',
#    'updated_at': '2019-09-06T11:38:57Z'},
#   {'id': '469a072',
#    'name': 'Wouter Vermeulen',
#    'firstname': 'Wouter',
#    'lastname': 'Vermeulen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '8176464B66',
#     'title': 'Front-End Developer (Divotion)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/340395/candidates/74029984',
#    'address': None,
#    'phone': None,
#    'email': 'wdvermeulen@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-02T13:38:13Z',
#    'updated_at': '2019-09-03T14:04:26Z'},
#   {'id': '469b33a',
#    'name': 'Spyridon Trastelis',
#    'firstname': 'Spyridon',
#    'lastname': 'Trastelis',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74034792',
#    'address': None,
#    'phone': '+31 0633608209',
#    'email': 'spirostrast@hotmail.com',
#    'domain': None,
#    'created_at': '2019-09-02T14:55:35Z',
#    'updated_at': '2019-09-03T08:52:51Z'},
#   {'id': '46a7440',
#    'name': 'Merel Lucia De Groot',
#    'firstname': 'Merel',
#    'lastname': 'Lucia De Groot',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': '1st Interview',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74084206',
#    'address': None,
#    'phone': '06 45 25 45 17',
#    'email': 'mereldg11@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-03T08:24:23Z',
#    'updated_at': '2019-09-06T11:35:31Z'},
#   {'id': '46a784d',
#    'name': 'Asif Aziz',
#    'firstname': 'Asif',
#    'lastname': 'Aziz',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Review',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/74085243',
#    'address': None,
#    'phone': '+31 642433332',
#    'email': 'azef.aziz@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-03T08:42:12Z',
#    'updated_at': '2019-09-11T11:00:34Z'},
#   {'id': '46a794f',
#    'name': 'Guido Sales Calvano',
#    'firstname': 'Guido',
#    'lastname': 'Sales Calvano',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/74085501',
#    'address': None,
#    'phone': None,
#    'email': 'guidocalvano@yahoo.com',
#    'domain': None,
#    'created_at': '2019-09-03T08:47:16Z',
#    'updated_at': '2019-09-06T14:55:49Z'},
#   {'id': '46bccfb',
#    'name': 'Bastiaan Verhoef',
#    'firstname': 'Bastiaan',
#    'lastname': 'Verhoef',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/74172457',
#    'address': None,
#    'phone': '0646718899',
#    'email': 'baverhoef@icloud.com',
#    'domain': None,
#    'created_at': '2019-09-04T08:22:15Z',
#    'updated_at': '2019-09-13T13:11:46Z'},
#   {'id': '46bccfc',
#    'name': 'Dorenda Slof',
#    'firstname': 'Dorenda',
#    'lastname': 'Slof',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/74172458',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-04T08:22:15Z',
#    'updated_at': '2019-09-04T08:27:02Z'},
#   {'id': '46bccfd',
#    'name': 'Yannis Katsaros',
#    'firstname': 'Yannis',
#    'lastname': 'Katsaros',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/74172459',
#    'address': None,
#    'phone': '06 1275 6173',
#    'email': 'johnkatsaros@outlook.com',
#    'domain': None,
#    'created_at': '2019-09-04T08:22:15Z',
#    'updated_at': '2019-09-13T11:30:46Z'},
#   {'id': '46c2996',
#    'name': 'Renate Van Kempen',
#    'firstname': 'Renate',
#    'lastname': 'Van Kempen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74196164',
#    'address': None,
#    'phone': None,
#    'email': 'renatekeijzer@hotmail.com',
#    'domain': None,
#    'created_at': '2019-09-04T14:24:21Z',
#    'updated_at': '2019-09-06T11:35:44Z'},
#   {'id': '46d43d6',
#    'name': 'Marcel Jepma',
#    'firstname': 'Marcel',
#    'lastname': 'Jepma',
#    'headline': 'Consultant and Cloud Reliability Engineer at Xebia B.V',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/74268420',
#    'address': 'Amsterdam, North Holland, Netherlands',
#    'phone': '+31 06 81289690',
#    'email': 'mjepma@xebia.com',
#    'domain': 'search',
#    'created_at': '2019-09-05T10:51:00Z',
#    'updated_at': '2019-09-11T07:43:18Z'},
#   {'id': '46e36f1',
#    'name': 'Ritchie Vink',
#    'firstname': 'Ritchie',
#    'lastname': 'Vink',
#    'headline': 'Data Scientist & Big Data Engineer at Xomnia',
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/74330655',
#    'address': 'Utrecht, Utrecht, Netherlands',
#    'phone': '+31 06 13227582',
#    'email': 'ritchie46@gmail.com',
#    'domain': 'search',
#    'created_at': '2019-09-06T05:27:49Z',
#    'updated_at': '2019-09-11T07:43:11Z'},
#   {'id': '46e6416',
#    'name': 'Arjan Bontsema',
#    'firstname': 'Arjan',
#    'lastname': 'Bontsema',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74342212',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-06T09:50:08Z',
#    'updated_at': '2019-09-09T08:41:03Z'},
#   {'id': '46e6418',
#    'name': 'Jan-Willem Feilzer',
#    'firstname': 'Jan-Willem',
#    'lastname': 'Feilzer',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74342214',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-06T09:50:09Z',
#    'updated_at': '2019-09-09T08:40:51Z'},
#   {'id': '46e8d87',
#    'name': 'Wesley Van Haren',
#    'firstname': 'Wesley',
#    'lastname': 'Van Haren',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '8176464B66',
#     'title': 'Front-End Developer (Divotion)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/340395/candidates/74352821',
#    'address': None,
#    'phone': '0618357277',
#    'email': 'wesleyvharen@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-06T13:16:44Z',
#    'updated_at': '2019-09-11T14:53:30Z'},
#   {'id': '46ea7e1',
#    'name': 'Daan Salomé',
#    'firstname': 'Daan',
#    'lastname': 'Salomé',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': '1st Interview',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74359567',
#    'address': None,
#    'phone': '+31 6-23764398',
#    'email': 'daansalome@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-06T14:57:42Z',
#    'updated_at': '2019-09-11T06:29:03Z'},
#   {'id': '4707add',
#    'name': 'Rob Jansen',
#    'firstname': 'Rob',
#    'lastname': 'Jansen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74479115',
#    'address': None,
#    'phone': '0650220470',
#    'email': None,
#    'domain': 'linkedin.com',
#    'created_at': '2019-09-09T08:20:46Z',
#    'updated_at': '2019-09-09T08:21:48Z'},
#   {'id': '4707d07',
#    'name': 'Denes Panta',
#    'firstname': 'Denes',
#    'lastname': 'Panta',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74479669',
#    'address': None,
#    'phone': '+43 664 9922 1985',
#    'email': 'dpanta.pvt@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-09T08:31:46Z',
#    'updated_at': '2019-09-09T12:56:49Z'},
#   {'id': '470a0e2',
#    'name': 'Sam Wolfs',
#    'firstname': 'Sam',
#    'lastname': 'Wolfs',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Review',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74488848',
#    'address': None,
#    'phone': '+ 32 471 83 21 81',
#    'email': 'be.samwolfs@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-09T11:30:06Z',
#    'updated_at': '2019-09-12T08:11:39Z'},
#   {'id': '470bbbc',
#    'name': 'Matthijs Van Kesteren',
#    'firstname': 'Matthijs',
#    'lastname': 'Van Kesteren',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74495722',
#    'address': None,
#    'phone': '+31636491172',
#    'email': 'mattie.vk@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-09T13:07:55Z',
#    'updated_at': '2019-09-11T11:12:10Z'},
#   {'id': '470c002',
#    'name': 'Hasina Atrafi',
#    'firstname': 'Hasina',
#    'lastname': 'Atrafi',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '08F7250588', 'title': 'Brand Manager'},
#    'stage': 'Review',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/1025608/candidates/74496816',
#    'address': None,
#    'phone': '(0)636108376',
#    'email': 'hasina.atrafi@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-09T13:22:13Z',
#    'updated_at': '2019-09-09T14:10:37Z'},
#   {'id': '471b4d0',
#    'name': 'Ruben Kluge',
#    'firstname': 'Ruben',
#    'lastname': 'Kluge',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': '1st Interview',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74559486',
#    'address': None,
#    'phone': '+31 6 34 50 52 12',
#    'email': 'ruben@kluge.nl',
#    'domain': None,
#    'created_at': '2019-09-10T07:22:23Z',
#    'updated_at': '2019-09-11T14:58:12Z'},
#   {'id': '471c3ae',
#    'name': 'Julia Boschan',
#    'firstname': 'Julia',
#    'lastname': 'Boschan',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74563292',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-10T08:40:19Z',
#    'updated_at': '2019-09-10T08:41:19Z'},
#   {'id': '471c3af',
#    'name': 'Jeffrey Den Otter',
#    'firstname': 'Jeffrey',
#    'lastname': 'Den Otter',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74563293',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-10T08:40:19Z',
#    'updated_at': '2019-09-11T07:02:06Z'},
#   {'id': '471c3b0',
#    'name': 'Martine Wester',
#    'firstname': 'Martine',
#    'lastname': 'Wester',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74563294',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-10T08:40:19Z',
#    'updated_at': '2019-09-10T08:40:46Z'},
#   {'id': '471c3b1',
#    'name': 'Iris Snuverink',
#    'firstname': 'Iris',
#    'lastname': 'Snuverink',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74563295',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-10T08:40:20Z',
#    'updated_at': '2019-09-10T08:40:38Z'},
#   {'id': '471c42a',
#    'name': 'Aurèle Morvan',
#    'firstname': 'Aurèle',
#    'lastname': 'Morvan',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Review',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/74563416',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-10T08:43:00Z',
#    'updated_at': '2019-09-13T14:49:37Z'},
#   {'id': '471c6d5',
#    'name': 'Anton Heijs',
#    'firstname': 'Anton',
#    'lastname': 'Heijs',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'To schedule',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/74564099',
#    'address': None,
#    'phone': '(+31) 6 53328272',
#    'email': 'anton@heijs.info',
#    'domain': None,
#    'created_at': '2019-09-10T08:54:32Z',
#    'updated_at': '2019-09-13T13:11:37Z'},
#   {'id': '47201bf',
#    'name': 'Lou Bakker',
#    'firstname': 'Lou',
#    'lastname': 'Bakker',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Review',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74579181',
#    'address': None,
#    'phone': '06-42621051',
#    'email': 'loujbakker@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-10T13:17:20Z',
#    'updated_at': '2019-09-11T11:28:43Z'},
#   {'id': '472f2b5',
#    'name': 'Leon Van Veldhuijzen',
#    'firstname': 'Leon',
#    'lastname': 'Van Veldhuijzen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': '2nd Interview',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74640867',
#    'address': None,
#    'phone': '0648471994',
#    'email': 'leon.vanveldhuijzen@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-11T08:23:17Z',
#    'updated_at': '2019-09-13T13:05:27Z'},
#   {'id': '472f4af',
#    'name': 'Nelson Mooren',
#    'firstname': 'Nelson',
#    'lastname': 'Mooren',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'F2E5FDE7A5', 'title': 'Big Data Engineer (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331681/candidates/74641373',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T08:35:20Z',
#    'updated_at': '2019-09-12T13:22:26Z'},
#   {'id': '472fb1a',
#    'name': 'Wouter Van Der Linde',
#    'firstname': 'Wouter',
#    'lastname': 'Van Der Linde',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643016',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:14Z',
#    'updated_at': '2019-09-11T09:11:23Z'},
#   {'id': '472fb1c',
#    'name': 'Michiel Mooy',
#    'firstname': 'Michiel',
#    'lastname': 'Mooy',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643018',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:15Z',
#    'updated_at': '2019-09-11T09:11:27Z'},
#   {'id': '472fb1d',
#    'name': 'Bert Veldkamp',
#    'firstname': 'Bert',
#    'lastname': 'Veldkamp',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643019',
#    'address': None,
#    'phone': None,
#    'email': 'bert225@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-11T09:11:15Z',
#    'updated_at': '2019-09-11T09:11:26Z'},
#   {'id': '472fb1f',
#    'name': 'Katia Asmoredjo',
#    'firstname': 'Katia',
#    'lastname': 'Asmoredjo',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643021',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:15Z',
#    'updated_at': '2019-09-13T08:27:55Z'},
#   {'id': '472fb20',
#    'name': 'Rik Wout',
#    'firstname': 'Rik',
#    'lastname': 'Wout',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643022',
#    'address': None,
#    'phone': '667871125',
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:15Z',
#    'updated_at': '2019-09-11T09:11:22Z'},
#   {'id': '472fb21',
#    'name': 'Robin De Jong',
#    'firstname': 'Robin',
#    'lastname': 'De Jong',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643023',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:15Z',
#    'updated_at': '2019-09-11T09:11:21Z'},
#   {'id': '472fb22',
#    'name': 'Marlou Van De Sande',
#    'firstname': 'Marlou',
#    'lastname': 'Van De Sande',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643024',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:16Z',
#    'updated_at': '2019-09-11T09:11:25Z'},
#   {'id': '472fb23',
#    'name': 'Ivar Reukers',
#    'firstname': 'Ivar',
#    'lastname': 'Reukers',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643025',
#    'address': None,
#    'phone': None,
#    'email': 'ivarreukers@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-11T09:11:16Z',
#    'updated_at': '2019-09-11T09:11:29Z'},
#   {'id': '472fb24',
#    'name': 'Tim Van Vliet',
#    'firstname': 'Tim',
#    'lastname': 'Van Vliet',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643026',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:16Z',
#    'updated_at': '2019-09-11T09:11:22Z'},
#   {'id': '472fb25',
#    'name': 'Max Umeh',
#    'firstname': 'Max',
#    'lastname': 'Umeh',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643027',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:16Z',
#    'updated_at': '2019-09-11T09:11:23Z'},
#   {'id': '472fb26',
#    'name': 'Aart Van Baren',
#    'firstname': 'Aart',
#    'lastname': 'Van Baren',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': True,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643028',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:16Z',
#    'updated_at': '2019-09-12T20:26:07Z'},
#   {'id': '472fb27',
#    'name': 'Sander Grootendorst',
#    'firstname': 'Sander',
#    'lastname': 'Grootendorst',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643029',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:16Z',
#    'updated_at': '2019-09-13T08:29:32Z'},
#   {'id': '472fb28',
#    'name': 'Coen Van Dam',
#    'firstname': 'Coen',
#    'lastname': 'Van Dam',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643030',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:16Z',
#    'updated_at': '2019-09-11T09:11:23Z'},
#   {'id': '472fb29',
#    'name': 'Tim Smeets',
#    'firstname': 'Tim',
#    'lastname': 'Smeets',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643031',
#    'address': None,
#    'phone': '+31633814886',
#    'email': 'timsmeets@rocketmail.com',
#    'domain': None,
#    'created_at': '2019-09-11T09:11:16Z',
#    'updated_at': '2019-09-11T09:11:27Z'},
#   {'id': '472fb2a',
#    'name': "Niels van 't Hof",
#    'firstname': 'Niels',
#    'lastname': "van 't Hof",
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643032',
#    'address': None,
#    'phone': None,
#    'email': 'niels@nielsvanthof.nl',
#    'domain': None,
#    'created_at': '2019-09-11T09:11:16Z',
#    'updated_at': '2019-09-11T09:13:28Z'},
#   {'id': '472fb2b',
#    'name': 'Jasper Kroes',
#    'firstname': 'Jasper',
#    'lastname': 'Kroes',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643033',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:17Z',
#    'updated_at': '2019-09-11T09:11:30Z'},
#   {'id': '472fb2c',
#    'name': 'Jan-Willem Den Dunnen',
#    'firstname': 'Jan-Willem',
#    'lastname': 'Den Dunnen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643034',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:17Z',
#    'updated_at': '2019-09-11T09:11:26Z'},
#   {'id': '472fb2d',
#    'name': 'Peter van der Wal',
#    'firstname': 'Peter',
#    'lastname': 'van der Wal',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643035',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:17Z',
#    'updated_at': '2019-09-11T09:12:22Z'},
#   {'id': '472fb2e',
#    'name': 'Jannemarie Dekens',
#    'firstname': 'Jannemarie',
#    'lastname': 'Dekens',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643036',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:17Z',
#    'updated_at': '2019-09-11T09:11:22Z'},
#   {'id': '472fb2f',
#    'name': 'Bram Tukker',
#    'firstname': 'Bram',
#    'lastname': 'Tukker',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643037',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:17Z',
#    'updated_at': '2019-09-11T09:11:26Z'},
#   {'id': '472fb30',
#    'name': 'Angela Brands',
#    'firstname': 'Angela',
#    'lastname': 'Brands',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643038',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:17Z',
#    'updated_at': '2019-09-11T11:22:50Z'},
#   {'id': '472fb31',
#    'name': 'Sander Krabbenborg',
#    'firstname': 'Sander',
#    'lastname': 'Krabbenborg',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643039',
#    'address': None,
#    'phone': '720790137',
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:17Z',
#    'updated_at': '2019-09-11T18:51:57Z'},
#   {'id': '472fb32',
#    'name': 'Alvaro Schipper',
#    'firstname': 'Alvaro',
#    'lastname': 'Schipper',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '46F9A9BEBD', 'title': 'Jr. Java Developer (JCore)'},
#    'stage': 'Sourced',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/331519/candidates/74643040',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T09:11:17Z',
#    'updated_at': '2019-09-11T11:22:30Z'},
#   {'id': '473146f',
#    'name': 'Thomas Ploeger',
#    'firstname': 'Thomas',
#    'lastname': 'Ploeger',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74649501',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T11:15:20Z',
#    'updated_at': '2019-09-11T11:16:57Z'},
#   {'id': '4731470',
#    'name': 'Stephanie Luik',
#    'firstname': 'Stephanie',
#    'lastname': 'Luik',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74649502',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T11:15:20Z',
#    'updated_at': '2019-09-11T11:16:46Z'},
#   {'id': '4731472',
#    'name': 'Jonathan Van De Ruitenbeek',
#    'firstname': 'Jonathan',
#    'lastname': 'Van De Ruitenbeek',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74649504',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T11:15:22Z',
#    'updated_at': '2019-09-11T11:16:34Z'},
#   {'id': '47314cf',
#    'name': 'Phuc Kien Nguyen',
#    'firstname': 'Phuc',
#    'lastname': 'Kien Nguyen',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/74649597',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T11:17:19Z',
#    'updated_at': '2019-09-11T11:18:13Z'},
#   {'id': '4731f1d',
#    'name': 'Edgar De Graaf',
#    'firstname': 'Edgar',
#    'lastname': 'De Graaf',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': 'A8C5321F60', 'title': 'Big Data Scientist (BDR)'},
#    'stage': 'Applied',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/329280/candidates/74652235',
#    'address': None,
#    'phone': None,
#    'email': None,
#    'domain': None,
#    'created_at': '2019-09-11T12:06:17Z',
#    'updated_at': '2019-09-11T18:51:03Z'},
#   {'id': '4734360',
#    'name': 'Jasper Mol',
#    'firstname': 'Jasper',
#    'lastname': 'Mol',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': '1st Interview',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74661518',
#    'address': None,
#    'phone': None,
#    'email': 'jaspermol95@hotmail.com',
#    'domain': None,
#    'created_at': '2019-09-11T14:12:37Z',
#    'updated_at': '2019-09-13T09:37:49Z'},
#   {'id': '4734f71',
#    'name': 'Dan Coman',
#    'firstname': 'Dan',
#    'lastname': 'Coman',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '8176464B66',
#     'title': 'Front-End Developer (Divotion)'},
#    'stage': 'Review',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/340395/candidates/74664607',
#    'address': None,
#    'phone': '+31622090488',
#    'email': 'dancoman@live.com',
#    'domain': None,
#    'created_at': '2019-09-11T14:54:28Z',
#    'updated_at': '2019-09-12T14:52:31Z'},
#   {'id': '4742d0b',
#    'name': 'Max Ortega',
#    'firstname': 'Max',
#    'lastname': 'Ortega',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'To schedule',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74721337',
#    'address': None,
#    'phone': '+31 653563356',
#    'email': 'maxdelvecchyo@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-12T08:37:57Z',
#    'updated_at': '2019-09-12T15:57:41Z'},
#   {'id': '4743315',
#    'name': 'Razieh Taghavi',
#    'firstname': 'Razieh',
#    'lastname': 'Taghavi',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Review',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74722883',
#    'address': None,
#    'phone': '+31626663766',
#    'email': 'raztaghavi@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-11T06:52:19Z',
#    'updated_at': '2019-09-13T09:37:39Z'},
#   {'id': '4747ac0',
#    'name': 'Sietse van der Bom',
#    'firstname': 'Sietse',
#    'lastname': 'van der Bom',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '8176464B66',
#     'title': 'Front-End Developer (Divotion)'},
#    'stage': 'Review',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/340395/candidates/74741230',
#    'address': None,
#    'phone': None,
#    'email': 'parqbanq@gmail.com',
#    'domain': None,
#    'created_at': '2019-09-12T14:22:50Z',
#    'updated_at': '2019-09-12T15:39:52Z'},
#   {'id': '4756569',
#    'name': 'Casper Slenders',
#    'firstname': 'Casper',
#    'lastname': 'Slenders',
#    'headline': None,
#    'account': {'subdomain': 'jdriven',
#     'name': 'JDriven/JCore/BigData Republic'},
#    'job': {'shortcode': '5E4DC1408A', 'title': 'Data Scientist (Vantage AI)'},
#    'stage': 'Review',
#    'disqualified': False,
#    'disqualification_reason': None,
#    'hired_at': None,
#    'sourced': True,
#    'profile_url': 'https://jdriven.workable.com/backend/jobs/686542/candidates/74801303',
#    'address': None,
#    'phone': None,
#    'email': 'casperslenders@live.nl',
#    'domain': None,
#    'created_at': '2019-09-13T10:43:20Z',
#    'updated_at': '2019-09-14T19:04:08Z'}]}

# %%
last_id = r.json()['candidates'][-1]['id']
last_id
# Out:
# '4756569'

# %%
# Build initial database

# Get first page
cand_id_list = []
workable_start_date = '2010-01-01T10:10:10Z'
r_cand = requests.get(url+'candidates?limit='+limit+'&created_after='+workable_start_date+'.json', headers=headers)
for cand in r_cand.json()['candidates']:
    cand_id_list.append(cand['id'])
    for k in key_list:
        loc = locate_element(cand,k)
        v = cand
        for i in loc:
            v = v[i]
        df_dict[k].append(v)
since_id=r_cand.json()['paging']['next'].split("since_id=",1)[1]

# Get next pages
try:
    while last_id not in cand_id_list:
        r_cand = requests.get('https://jdriven.workable.com/spi/v3/candidates?limit=100&since_id='+since_id+'.json', headers=headers)
        for cand in r_cand.json()['candidates']:
            cand_id_list.append(cand['id'])
            for k in key_list:
                loc = locate_element(cand,k)
                v = cand
                for i in loc:
                    v = v[i]
                df_dict[k].append(v)
        since_id=r_cand.json()['paging']['next'].split("since_id=",1)[1]
except KeyError:
    print('Last candidate entry retrieved')
    last_id = cand_id_list[-1]
    last_id
# Out:
# Last candidate entry retrieved

# %%
cand_id_list
# Out:
# ['ddb204',
#  'ddb571',
#  'ddb572',
#  'ddb582',
#  'ddb9ca',
#  'ddbfa2',
#  'ddf173',
#  'ddf20e',
#  'ddf485',
#  'ddf4cd',
#  'ddf4d2',
#  'ddf7b4',
#  'ddfcbd',
#  'ddfe84',
#  'de4088',
#  'de4522',
#  'de463d',
#  'de47a3',
#  'de489d',
#  'de53cd',
#  'de5bfa',
#  'de5d64',
#  'df6c94',
#  'df77d7',
#  'df78b9',
#  'df87cf',
#  'df8812',
#  'dfaacc',
#  'dfaf18',
#  'e00269',
#  'e01304',
#  'e01384',
#  'e03bca',
#  'e096e5',
#  'e11c35',
#  'e12f8f',
#  'e1cca6',
#  'e23fde',
#  'e27389',
#  'e2d0e6',
#  'e2d1ee',
#  'e2d3f3',
#  'e2d4ac',
#  'e2d5c4',
#  'e2d75b',
#  'e2e573',
#  'e3016e',
#  'e36bc6',
#  'e37c6f',
#  'e3c572',
#  'e48b5d',
#  'e48ca1',
#  'e48dcf',
#  'e48e52',
#  'e4f7dd',
#  'e50701',
#  'e51018',
#  'e58576',
#  'e5a36a',
#  'e62144',
#  'e625d1',
#  'e626f8',
#  'e638d2',
#  'e66728',
#  'e67a26',
#  'e67b0f',
#  'e67bb3',
#  'e67d9a',
#  'e6af5b',
#  'e6bf82',
#  'e6c2b9',
#  'e6c31d',
#  'e6c355',
#  'e7d4fb',
#  'e7e78e',
#  'e7fb23',
#  'e8132b',
#  'e81351',
#  'e86ad3',
#  'e86bc0',
#  'e875d1',
#  'e88844',
#  'e991c1',
#  'e991e5',
#  'e99a03',
#  'e9a3af',
#  'e9a3b0',
#  'ea0e8f',
#  'ea1045',
#  'ea178d',
#  'ea22b7',
#  'eacf37',
#  'eacfad',
#  'eacfe0',
#  'ead014',
#  'ead061',
#  'eb1555',
#  'eb2cf8',
#  'eb4afd',
#  'ebb4b0',
#  'ebb4b1',
#  'ebbf82',
#  'ebc62b',
#  'ec4be3',
#  'ec4c1d',
#  'ec65c9',
#  'ec75a3',
#  'ecda2c',
#  'ece8db',
#  'ed5f45',
#  'ed6ba3',
#  'ed6bae',
#  'ed6bfc',
#  'ed6c0a',
#  'ed6c51',
#  'ed6c94',
#  'ed6dd8',
#  'eea577',
#  'eeadf9',
#  'eec176',
#  'eec992',
#  'eedca0',
#  'eedf9b',
#  'eee10a',
#  'eee597',
#  'ef5e75',
#  'ef613f',
#  'ef6b47',
#  'ef81c5',
#  'f00145',
#  'f02333',
#  'f02334',
#  'f02335',
#  'f0776b',
#  'f078ce',
#  'f08104',
#  'f09fa8',
#  'f0c55a',
#  'f0d3ca',
#  'f1bd9b',
#  'f22936',
#  'f2299a',
#  'f23023',
#  'f230e3',
#  'f2cd35',
#  'f2cece',
#  'f2fed1',
#  'f36867',
#  'f36d06',
#  'f36d1c',
#  'f36d27',
#  'f36d5a',
#  'f36d7c',
#  'f36d92',
#  'f36da4',
#  'f36daf',
#  'f36dc1',
#  '13126a6',
#  '13126c6',
#  '1312708',
#  '13127d9',
#  '131286f',
#  '13128fe',
#  '1312940',
#  '13129b7',
#  '1312a2f',
#  '1312b42',
#  '1314095',
#  '1314db0',
#  '1314e3b',
#  '1315b3d',
#  '1315e3d',
#  '1315f57',
#  '1320082',
#  '13214ab',
#  '1321f76',
#  '132bbab',
#  '132bdd7',
#  '132bf29',
#  '132c014',
#  '132cf28',
#  '132d0da',
#  '132d132',
#  '132d48e',
#  '132d5ab',
#  '132d601',
#  '132d766',
#  '132db5c',
#  '132e0ba',
#  '132e117',
#  '132e4e1',
#  '132f13c',
#  '132f40d',
#  '1330346',
#  '1337c0a',
#  '13384f5',
#  '1339bd6',
#  '1342d54',
#  '134e4a1',
#  '135a1f9',
#  '135a63c',
#  '135a861',
#  '135b480',
#  '135b72e',
#  '135b9b9',
#  '135baad',
#  '135bbce',
#  '135bc43',
#  '135bcfd',
#  '1368a41',
#  '13692ae',
#  '1374114',
#  '1374232',
#  '1374464',
#  '1374fa2',
#  '1376292',
#  '13762bb',
#  '13762ff',
#  '137632d',
#  '137635b',
#  '1376444',
#  '137665b',
#  '1376698',
#  '13766c4',
#  '13766f1',
#  '1376740',
#  '1376831',
#  '1376b79',
#  '1376db2',
#  '13775d6',
#  '1377710',
#  '13777ad',
#  '137784b',
#  '137798d',
#  '1377c88',
#  '1380674',
#  '1381cfc',
#  '138294c',
#  '139467f',
#  '13960b6',
#  '139611a',
#  '13961ac',
#  '1396318',
#  '1396384',
#  '1396524',
#  '1396b37',
#  '13a1fce',
#  '13a205a',
#  '13a2247',
#  '13a2256',
#  '13a22e7',
#  '13a2338',
#  '13a30df',
#  '13a336e',
#  '13a34fb',
#  '13a36d5',
#  '13a37ba',
#  '13a3820',
#  '13a3afa',
#  '13a3bb4',
#  '13aca82',
#  '13acb5b',
#  '13acc5e',
#  '13acd6b',
#  '13ae1f8',
#  '13ae2de',
#  '13ae466',
#  '13b7a08',
#  '13b7a89',
#  '13b7ccf',
#  '13b9251',
#  '13b9532',
#  '13b987e',
#  '13b992b',
#  '13b99c3',
#  '13b9ae1',
#  '13baaf9',
#  '13bb0c0',
#  '13bb279',
#  '13bc014',
#  '13bd161',
#  '13c2465',
#  '13d832f',
#  '13d8342',
#  '13d87a9',
#  '13d8ec9',
#  '13d9101',
#  '13d9a5b',
#  '13e4823',
#  '13e4883',
#  '13e4926',
#  '13e498d',
#  '13e4a7d',
#  '13e4ac3',
#  '13e4b01',
#  '13e4b54',
#  '13e4b5a',
#  '13e4b5f',
#  '13e4d1d',
#  '13e4d20',
#  '13e4d29',
#  '13e4d2d',
#  '13e4d2f',
#  '13e4d34',
#  '13e4d39',
#  '13e4d3e',
#  '13e4d41',
#  '13e509c',
#  '13e50a3',
#  '13e50ab',
#  '13e50ae',
#  '13e50b0',
#  '13e50b7',
#  '13e50b9',
#  '13e60c7',
#  '13e60f9',
#  ...]

# %%
def update_cand_db(last_id, cand_id_list):
    '''
    Update candidate database with any new candidates added after last candidate entry in DB
    Key Arguments:
    last_id -- id of last entry of the candidate database
    '''
    #Retrieve latest candidates
    r_cand_upd = requests.get(url+'candidates?limit='+limit+'&since_id='+last_id+'.json', headers=headers)
    if len(r_cand_upd.json()['candidates'])>1: # first item in the candidates list is already in the DB
        for new_cand in r_cand_upd.json()['candidates'][1:]:
            cand_id_list.append(new_cand['id'])
        last_id=new_cand['id']
        return cand_id_list
    else:
        print('Nothing to add')
        print(cand_id_list[-1])

# %%
update_cand_db(last_id, cand_id_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-796e19a8bb07> in <module>
# ----> 1 update_cand_db(last_id, cand_id_list)
#
# NameError: name 'update_cand_db' is not defined

# %%
cand_id_list[-1]
# Out:
# '4756569'

# %%
# Create DataFrame
df = pd.DataFrame.from_dict(df_dict, orient='columns')

# %%
df.tail()
# Out:
#            id                name firstname     lastname headline subdomain  \
# 5040  4734f71           Dan Coman       Dan        Coman     None   jdriven
# 5041  4742d0b          Max Ortega       Max       Ortega     None   jdriven
# 5042  4743315      Razieh Taghavi    Razieh      Taghavi     None   jdriven
# 5043  4747ac0  Sietse van der Bom    Sietse  van der Bom     None   jdriven
# 5044  4756569     Casper Slenders    Casper     Slenders     None   jdriven
#
#        shortcode                           title        stage  disqualified  \
# 5040  8176464B66  Front-End Developer (Divotion)       Review         False
# 5041  5E4DC1408A     Data Scientist (Vantage AI)  To schedule         False
# 5042  5E4DC1408A     Data Scientist (Vantage AI)       Review         False
# 5043  8176464B66  Front-End Developer (Divotion)       Review         False
# 5044  5E4DC1408A     Data Scientist (Vantage AI)       Review         False
#
#      disqualification_reason hired_at  sourced  \
# 5040                    None     None     True
# 5041                    None     None     True
# 5042                    None     None     True
# 5043                    None     None     True
# 5044                    None     None     True
#
#                                             profile_url address  \
# 5040  https://jdriven.workable.com/backend/jobs/3403...    None
# 5041  https://jdriven.workable.com/backend/jobs/6865...    None
# 5042  https://jdriven.workable.com/backend/jobs/6865...    None
# 5043  https://jdriven.workable.com/backend/jobs/3403...    None
# 5044  https://jdriven.workable.com/backend/jobs/6865...    None
#
#               phone                    email domain            created_at  \
# 5040   +31622090488        dancoman@live.com   None  2019-09-11T14:54:28Z
# 5041  +31 653563356  maxdelvecchyo@gmail.com   None  2019-09-12T08:37:57Z
# 5042   +31626663766     raztaghavi@gmail.com   None  2019-09-11T06:52:19Z
# 5043           None       parqbanq@gmail.com   None  2019-09-12T14:22:50Z
# 5044           None   casperslenders@live.nl   None  2019-09-13T10:43:20Z
#
#                 updated_at
# 5040  2019-09-12T14:52:31Z
# 5041  2019-09-12T15:57:41Z
# 5042  2019-09-13T09:37:39Z
# 5043  2019-09-12T15:39:52Z
# 5044  2019-09-14T19:04:08Z

# %%
d = r_cand.json()['candidates'][0]

# %%
d = change_name_duplicate_keys(d)

# %%
d

# %%
locate_element()

# %%
df_cop = copy.deepcopy(df)
df_cop.head()
# Out:
#        id                     name         firstname       lastname headline  \
# 0  ddb204              Niels Drost             Niels          Drost     None
# 1  ddb571    Paula L Amaral Santos           Paula L  Amaral Santos     None
# 2  ddb572         Gulliver de Boer          Gulliver        de Boer     None
# 3  ddb582           Pieter Kouyzer            Pieter        Kouyzer     None
# 4  ddb9ca  Profiel Van Aris Koning  Profiel Van Aris         Koning     None
#
#   subdomain   shortcode                     title          stage  \
# 0   jdriven  A8C5321F60  Big Data Scientist (BDR)  1st Interview
# 1   jdriven  A8C5321F60  Big Data Scientist (BDR)          Hired
# 2   jdriven  A8C5321F60  Big Data Scientist (BDR)  2nd Interview
# 3   jdriven  A8C5321F60  Big Data Scientist (BDR)     Talentpool
# 4   jdriven  A8C5321F60  Big Data Scientist (BDR)  2nd Interview
#
#    disqualified disqualification_reason              hired_at  sourced  \
# 0          True                    None                  None     True
# 1         False                    None  2016-10-14T10:04:42Z     True
# 2          True                    None                  None     True
# 3         False                    None                  None     True
# 4          True                    None                  None     True
#
#                                          profile_url address  \
# 0  https://jdriven.workable.com/backend/jobs/3292...    None
# 1  https://jdriven.workable.com/backend/jobs/3292...    None
# 2  https://jdriven.workable.com/backend/jobs/3292...    None
# 3  https://jdriven.workable.com/backend/jobs/3292...    None
# 4  https://jdriven.workable.com/backend/jobs/3292...    None
#
#               phone                              email domain  \
# 0   +31 6 1543 4021              niels.drost@gmail.com   None
# 1              None               paula.amrl@gmail.com   None
# 2      +31612085780                gulif87@hotmail.com   None
# 3  +31(0)85 0020019  joris.braspenning@careerresult.nl   None
# 4              None        frank.kurstjens@jdriven.com   None
#
#              created_at            updated_at
# 0  2016-09-05T10:05:28Z  2019-02-01T14:56:34Z
# 1  2016-09-05T10:51:00Z  2019-01-08T12:17:22Z
# 2  2016-09-05T10:51:04Z  2019-01-28T10:34:24Z
# 3  2016-09-05T10:52:07Z  2019-02-01T14:52:58Z
# 4  2016-09-05T11:49:31Z  2019-01-10T14:29:23Z

# %%
str(df_cop['id'].dtype)
# Out:
# 'object'

# %%
df_cop.isnull().sum()
# Out:
# id                            0
# name                          0
# firstname                     6
# lastname                      5
# headline                   4527
# subdomain                     0
# shortcode                     0
# title                         0
# stage                         0
# disqualified                  0
# disqualification_reason    5045
# hired_at                   4960
# sourced                       0
# profile_url                   0
# address                    4544
# phone                      3198
# email                      2332
# domain                     4906
# created_at                    0
# updated_at                    0
# dtype: int64

# %%
df_cop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5045 entries, 0 to 5044
# Data columns (total 20 columns):
# id                         5045 non-null object
# name                       5045 non-null object
# firstname                  5039 non-null object
# lastname                   5040 non-null object
# headline                   518 non-null object
# subdomain                  5045 non-null object
# shortcode                  5045 non-null object
# title                      5045 non-null object
# stage                      5045 non-null object
# disqualified               5045 non-null bool
# disqualification_reason    0 non-null object
# hired_at                   85 non-null object
# sourced                    5045 non-null bool
# profile_url                5045 non-null object
# address                    501 non-null object
# phone                      1847 non-null object
# email                      2713 non-null object
# domain                     139 non-null object
# created_at                 5045 non-null object
# updated_at                 5045 non-null object
# dtypes: bool(2), object(18)
# memory usage: 719.4+ KB

# %%
# Create sql_create_table_query = ... columns and data type
col_dt = []
for col in df_cop.columns.tolist():
    col_dt.append(col+' '+str(df_cop[col].dtype))
#Replace objects with TEXT
col_dt = [s.replace('object', 'TEXT') for s in col_list]
table_col = ','.join(col_dt)
table_col
# Out:
# ['id object',
#  'name object',
#  'firstname object',
#  'lastname object',
#  'headline object',
#  'subdomain object',
#  'shortcode object',
#  'title object',
#  'stage object',
#  'disqualified bool',
#  'disqualification_reason object',
#  'hired_at object',
#  'sourced bool',
#  'profile_url object',
#  'address object',
#  'phone object',
#  'email object',
#  'domain object',
#  'created_at object',
#  'updated_at object']

# %%
col_list = ['id object',
 'name object',
 'firstname object',
 'lastname object',
 'headline object',
 'subdomain object',
 'shortcode object',
 'title object',
 'stage object',
 'disqualified bool',
 'disqualification_reason object',
 'hired_at object',
 'sourced bool',
 'profile_url object',
 'address object',
 'phone object',
 'email object',
 'domain object',
 'created_at object',
 'updated_at object']

# %%
col_dt = [s.replace('object', 'TEXT') for s in col_list]
table_col = ','.join(col_dt)
table_col
# Out:
# 'id TEXT,name TEXT,firstname TEXT,lastname TEXT,headline TEXT,subdomain TEXT,shortcode TEXT,title TEXT,stage TEXT,disqualified bool,disqualification_reason TEXT,hired_at TEXT,sourced bool,profile_url TEXT,address TEXT,phone TEXT,email TEXT,domain TEXT,created_at TEXT,updated_at TEXT'

# %%
# object is not a data type that can be parsed into CREATE TABLE statement, need to convert into TEXT?

# %%
import mysql.connector
conn = mysql.connector.connect(user='root', password='maartens1991',host='localhost', database='recruitment_dashboard')
cursor = conn.cursor()

# Create table
cursor.execute('''CREATE TABLE candidates
             (date TEXT, trans TEXT, symbol TEXT, qty INT, price REAL)''')

# Save (commit) the changes
conn.commit()

# Select column names in order from 1st to last column
sql_select_query = '''SELECT column_name
FROM information_schema.columns
WHERE table_schema = 'recruitment_dashboard'
AND table_name   = 'candidates'
ORDER BY ORDINAL_POSITION
'''

cursor = conn.cursor()
cursor.execute(sql_select_query)
records = cursor.fetchall() 
columns = []
for i in records:
    columns.append(i[0])
col_n = ','.join(columns)

params = ['%s' for item in records_to_insert[0]] # always use '%s' no matter the data type of the column
var_string = ','.join(params)

#Records to insert in SQL table
records_to_insert = [('2011-01-05','SELL','CAPITAL',13300,40.14),('2010-01-05','BUY','RHAT',2000,35.14),('2006-01-05','BUY','RHAT',800,35.14),]

#Insert all records into table
sql_insert_query = """INSERT INTO candidates (%s) VALUES (%s);""" %(col_n,var_string)
cursor = conn.cursor()
cursor.executemany(sql_insert_query, records_to_insert)

#Commit all changes
conn.commit()

#Close the connection
conn.close()


except (Exception, mysql.Error) as error :
    print ("Error while connecting to SQL DB", error)
finally:
    #Closing database connection.
    if(conn):
        cursor.close()
        connection.close()
        print("SQL DB connection is closed")

# %%
try:
    connection = mysql.connector.connect(user='root', password='maartens1991',host='localhost', database='recruitment_dashboard')
    create_table_q = '''
    CREATE TABLE candidates (
    tconst varchar,
    titleType varchar,
    primaryTitle varchar,
    originalTitle varchar,
    isAdult varchar,
    startYear varchar,
    endYear varchar,
    runtimeMinutes varchar,
    genres varchar,
    primary key (tconst)
    );'''
    
    cursor = connection.cursor()
    cursor.execute(create_table_q)
    connection.commit()
    
    sql_select_query = '''SELECT column_name
    FROM information_schema.columns
    WHERE table_schema = 'recruitment_dashboard'
    AND table_name   = 'candidates'
    '''
    
    cursor = connection.cursor()
    cursor.execute(sql_select_query)
    records = cursor.fetchall()
    columns = []
    for i in records:
        columns.append(i[0])
    col_n = ','.join(columns)
    
except (Exception, psycopg2.Error) as error :
    print ("Error while connecting to PostgreSQL", error)
finally:
    #Closing database connection.
    if(connection):
        cursor.close()
        connection.close()
        print("PostgreSQL connection is closed")
